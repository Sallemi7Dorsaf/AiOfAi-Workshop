# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 98.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 119.9 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.28.1

# %%
import io
import os
import torch
from tqdm.notebook import tqdm
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import classification_report, accuracy_score
from transformers import (set_seed,
                          TrainingArguments,
                          Trainer,
                          GPT2Config,
                          GPT2Tokenizer,
                          AdamW, 
                          get_linear_schedule_with_warmup,
                          GPT2ForSequenceClassification)

# %%
model_name_or_path = 'gpt2'

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Read dataset file

# %%
import pandas as pd
import numpy as np

train_filename = "/content/drive/MyDrive/NLP Project/Datasets/AFND/train.csv"
test_filename = "/content/drive/MyDrive/NLP Project/Datasets/AFND/test.csv"




df_train = pd.read_csv(train_filename)
df_test = pd.read_csv(test_filename)

# %%
label_mapping = {1:'fake', 0:'real'}
df_train.label = df_train.label.map(label_mapping)
df_test.label = df_test.label.map(label_mapping)

# %%
df_train.head()
# Out:
#                                                 text label
# 0  ايران تبدا اختبار انظمة التبريد مفاعل اراكستخت...  real
# 1  بومبيو استبعد ترشحي انتخابات الراسة الامريكية ...  real
# 2  هبوطا باسعار النفط عقب اعلان تعويم السفينة الب...  real
# 3  عودة المهاجرين فرنسا ستكون وفق الاطر القانونية...  fake
# 4  ريس الوزرا يتفقد مركز لقاحات كورونا بارض المعا...  real

# %%
df_test.head()
# Out:
#                                                 text label
# 0  وفيات الثلاثا اقرا ايضا وفيات وعشرات الاصابات ...  fake
# 1  الضمان مدرسة تعهدت بتقديم رسوم سواليف قال النا...  fake
# 2  اقل الف وفاة يومية بكورونا امريكا للمرة الاولي...  fake
# 3  تتدخل مسال اجتماعية تعنيكعلق الامين العام السا...  fake
# 4  وفاة الامير فيليب زوج ملكة بريطانيا الملكة الي...  fake

# %%
df_train.loc[df_train.label == 'fake'].sample(10)
# Out:
#                                                     text label
# 36407  مراكش تواصل حملة التبرع بالدم بكلية الاداب وال...  fake
# 59058  سفير المانيا بالقاهرة التعاون التعليم العالي و...  fake
# 52974  وصول الشحنة الاولي لقاح فايزر الامريكي الي طرا...  fake
# 44908  بيروت وبغداد النفط مقابل العلاجوقع لبنان والعر...  fake
# 58820  الدبيبة يقدم قامة حكومة الوحدة الوطنية الخميسق...  fake
# 49049  ضبط سلاح نوع كارلو واعتقال مشتبه مجد الكرومجا ...  fake
# 2789   الجيش الصحراوي ينفذ هجمات جديدة ضد تخندقات جنو...  fake
# 11312  يمكن للجامعة ان تلغي عقوبة الشابة اللجو الي جل...  fake
# 6656   الغا نقلة بشير العكرمي وكالة الجمهورية بتونس ق...  fake
# 54928  فعاليات اليومين الثاني والثالث والتوصيات للمنت...  fake

# %% [markdown]
# ### Get the values of DataFrame

# %%
train_labels = df_train['label'].tolist()
train_text = df_train['text'].tolist()

test_labels = df_test['label'].tolist()
test_text = df_test['text'].tolist()

assert len(train_labels) == len(train_text)
assert len(test_labels) == len(test_text)

print("len(train_text) = {}, len(test_text) = {}".format(len(train_text), len(test_text)))
# Out:
# len(train_text) = 64000, len(test_text) = 16000

# %%
def unique(list1):
 
    # initialize a null list
    unique_list = []
 
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    for x in unique_list:
        print (x)

# %%
unique(train_labels)
# Out:
# real
# fake

# %% [markdown]
# ### Get values indices

# %%
def format_label_value(labels):
    """
    Formats a list of labels to corresponding numeric values.
    """
    format_label_list = []

    for label in labels:
        if label == "fake":
            format_label_list.append(0)
        elif label == "real":
            format_label_list.append(1)
        
    
    return format_label_list

# %%
train_labels = format_label_value(train_labels)
test_labels = format_label_value(test_labels)

# %%
len(train_labels)
# Out:
# 64000

# %% [markdown]
# ## GPT2 Tokenization & Input Formatting

# %% [markdown]
# ### GPT2 Tokenization

# %%
# Get model configuration.
print('Loading configuraiton...')
model_config = GPT2Config.from_pretrained(pretrained_model_name_or_path=model_name_or_path, num_labels=2)

# Get model's tokenizer.
print('Loading tokenizer...')
tokenizer = GPT2Tokenizer.from_pretrained(pretrained_model_name_or_path=model_name_or_path)
# default to left padding
tokenizer.padding_side = "left"
# Define PAD Token = EOS Token = 50256
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Loading configuraiton...
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Loading tokenizer...
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
# Print the original sentence.
print('Original: ', train_text[0])
print("len(Original) = ", len(train_text[0]))
print("\n")

# Print the sentence split into tokens.
print('Tokenized: ', tokenizer.tokenize(train_text[0]))
print("len(Tokenized) = ", len(tokenizer.tokenize(train_text[0])))
print("\n")

# Print the sentence mapped to token ids.
print('Token IDs: ', tokenizer.convert_tokens_to_ids(tokenizer.tokenize(train_text[0])))
print("len(Token IDs) = ", len(tokenizer.convert_tokens_to_ids(tokenizer.tokenize(train_text[0]))))
print("\n")
# Out:
# Original:  ايران تبدا اختبار انظمة التبريد مفاعل اراكستختبر ايران انظمة التبريد مفاعل اراك النووي تمهيدا لتشغيله بشكل كامل العام اعلنت منظمة الطاقة الذرية الايرانية اليوم الجمعة ونقلت وسال اعلام المتحدث باسم المنظمة بهروز كمالوندي قوله ان اختبار التبريد يشمل عادة تشغيل انظمة السوال وانظمة الدعم سيكون اوال السنة الفارسية الجديدة تبدا يوم الاحد المقبل وقال كمالوندي بمعني اخر حققنا تقدما العمل بقطاعات الوقود والتخزين وزادت ايران الاونة الاخيرة وتيرة انتهاك بنود الاتفاق النووي الدولي الموقع عام محاولة يبدو للضغط الريس الامريكي جو بايدن للعدول قرار سلفه دونالد ترامب الانسحاب الاتفاق والمواجهة قامة الجانبين يجب ان يبادر بالتحرك لانقاذ الاتفاق كانت ايران وافقت اغلاق مفاعل اراك يقع كيلومترا طهران بموجب اتفاق مسموحا بانتاج كمية محدودة الما الثقيل عملت اعادة تصميم المفاعل تقول انها تعتزم انتاج نظار لاغراض طبية وزراعية وقالت الوكالة الدولية للطاقة الذرية تقرير لدولها الاعضا الاسبوع ان ايران بدات تخصيب اليورانيوم محطة نطنز الارض باستخدام نوع ثان اجهزة الطرد المركزي المتقدمة اي ار انتهاك جديد للاتفاق
# len(Original) =  992
#
#
# Tokenized:  ['Ø§', 'ÙĬ', 'Ø±', 'Ø§', 'ÙĨ', 'ĠØ', 'ª', 'Ø¨', 'Ø¯', 'Ø§', 'Ġ', 'Ø§Ø', '®', 'Øª', 'Ø¨', 'Ø§', 'Ø±', 'Ġ', 'Ø§', 'ÙĨ', 'Ø', '¸', 'Ùħ', 'Ø©', 'ĠØ§ÙĦ', 'Øª', 'Ø¨', 'Ø±', 'ÙĬ', 'Ø¯', 'ĠÙħ', 'Ù', 'ģ', 'Ø§Ø', '¹', 'ÙĦ', 'Ġ', 'Ø§', 'Ø±', 'Ø§', 'Ù', 'ĥ', 'Ø³', 'Øª', 'Ø', '®', 'Øª', 'Ø¨', 'Ø±', 'Ġ', 'Ø§', 'ÙĬ', 'Ø±', 'Ø§', 'ÙĨ', 'Ġ', 'Ø§', 'ÙĨ', 'Ø', '¸', 'Ùħ', 'Ø©', 'ĠØ§ÙĦ', 'Øª', 'Ø¨', 'Ø±', 'ÙĬ', 'Ø¯', 'ĠÙħ', 'Ù', 'ģ', 'Ø§Ø', '¹', 'ÙĦ', 'Ġ', 'Ø§', 'Ø±', 'Ø§', 'Ù', 'ĥ', 'ĠØ§ÙĦ', 'ÙĨ', 'ÙĪ', 'ÙĪ', 'ÙĬ', 'ĠØ', 'ª', 'Ùħ', 'Ùĩ', 'ÙĬ', 'Ø¯', 'Ø§', 'Ġ', 'ÙĦ', 'Øª', 'Ø', '´', 'Ø', 'º', 'ÙĬ', 'ÙĦ', 'Ùĩ', 'ĠØ', '¨', 'Ø', '´', 'Ù', 'ĥ', 'ÙĦ', 'ĠÙ', 'ĥ', 'Ø§', 'Ùħ', 'ÙĦ', 'ĠØ§ÙĦ', 'Ø¹', 'Ø§', 'Ùħ', 'Ġ', 'Ø§Ø', '¹', 'ÙĦ', 'ÙĨ', 'Øª', 'ĠÙħ', 'ÙĨ', 'Ø', '¸', 'Ùħ', 'Ø©', 'ĠØ§ÙĦ', 'Ø', '·', 'Ø§', 'Ù', 'Ĥ', 'Ø©', 'ĠØ§ÙĦ', 'Ø', '°', 'Ø±', 'ÙĬ', 'Ø©', 'ĠØ§ÙĦ', 'Ø§', 'ÙĬ', 'Ø±', 'Ø§', 'ÙĨ', 'ÙĬ', 'Ø©', 'ĠØ§ÙĦ', 'ÙĬ', 'ÙĪ', 'Ùħ', 'ĠØ§ÙĦ', 'Ø', '¬', 'Ùħ', 'Ø¹', 'Ø©', 'ĠÙĪ', 'ÙĨ', 'Ù', 'Ĥ', 'ÙĦ', 'Øª', 'ĠÙĪ', 'Ø³', 'Ø§ÙĦ', 'Ġ', 'Ø§Ø', '¹', 'ÙĦ', 'Ø§', 'Ùħ', 'ĠØ§ÙĦ', 'Ùħ', 'Øª', 'Ø', 'Ń', 'Ø¯', 'Ø', '«', 'ĠØ', '¨', 'Ø§Ø', '³', 'Ùħ', 'ĠØ§ÙĦ', 'Ùħ', 'ÙĨ', 'Ø', '¸', 'Ùħ', 'Ø©', 'ĠØ', '¨', 'Ùĩ', 'Ø±', 'ÙĪ', 'Ø', '²', 'ĠÙ', 'ĥ', 'Ùħ', 'Ø§ÙĦ', 'ÙĪ', 'ÙĨ', 'Ø¯', 'ÙĬ', 'ĠÙ', 'Ĥ', 'ÙĪ', 'ÙĦ', 'Ùĩ', 'Ġ', 'Ø§', 'ÙĨ', 'Ġ', 'Ø§Ø', '®', 'Øª', 'Ø¨', 'Ø§', 'Ø±', 'ĠØ§ÙĦ', 'Øª', 'Ø¨', 'Ø±', 'ÙĬ', 'Ø¯', 'ĠÙ', 'Ĭ', 'Ø', '´', 'Ùħ', 'ÙĦ', 'ĠØ', '¹', 'Ø§Ø', '¯', 'Ø©', 'ĠØ', 'ª', 'Ø', '´', 'Ø', 'º', 'ÙĬ', 'ÙĦ', 'Ġ', 'Ø§', 'ÙĨ', 'Ø', '¸', 'Ùħ', 'Ø©', 'ĠØ§ÙĦ', 'Ø³', 'ÙĪ', 'Ø§ÙĦ', 'ĠÙĪ', 'Ø§', 'ÙĨ', 'Ø', '¸', 'Ùħ', 'Ø©', 'ĠØ§ÙĦ', 'Ø¯', 'Ø¹', 'Ùħ', 'ĠØ', '³', 'ÙĬ', 'Ù', 'ĥ', 'ÙĪ', 'ÙĨ', 'Ġ', 'Ø§', 'ÙĪ', 'Ø§ÙĦ', 'ĠØ§ÙĦ', 'Ø³', 'ÙĨ', 'Ø©', 'ĠØ§ÙĦ', 'Ù', 'ģ', 'Ø§', 'Ø±', 'Ø³', 'ÙĬ', 'Ø©', 'ĠØ§ÙĦ', 'Ø', '¬', 'Ø¯', 'ÙĬ', 'Ø¯', 'Ø©', 'ĠØ', 'ª', 'Ø¨', 'Ø¯', 'Ø§', 'ĠÙ', 'Ĭ', 'ÙĪ', 'Ùħ', 'ĠØ§ÙĦ', 'Ø§Ø', 'Ń', 'Ø¯', 'ĠØ§ÙĦ', 'Ùħ', 'Ù', 'Ĥ', 'Ø¨', 'ÙĦ', 'ĠÙĪ', 'Ù', 'Ĥ', 'Ø§ÙĦ', 'ĠÙ', 'ĥ', 'Ùħ', 'Ø§ÙĦ', 'ÙĪ', 'ÙĨ', 'Ø¯', 'ÙĬ', 'ĠØ', '¨', 'Ùħ', 'Ø¹', 'ÙĨ', 'ÙĬ', 'Ġ', 'Ø§Ø', '®', 'Ø±', 'ĠØ', 'Ń', 'Ù', 'Ĥ', 'Ù', 'Ĥ', 'ÙĨ', 'Ø§', 'ĠØ', 'ª', 'Ù', 'Ĥ', 'Ø¯', 'Ùħ', 'Ø§', 'ĠØ§ÙĦ', 'Ø¹', 'Ùħ', 'ÙĦ', 'ĠØ', '¨', 'Ù', 'Ĥ', 'Ø', '·', 'Ø§Ø', '¹', 'Ø§Ø', 'ª', 'ĠØ§ÙĦ', 'ÙĪ', 'Ù', 'Ĥ', 'ÙĪ', 'Ø¯', 'ĠÙĪ', 'Ø§ÙĦ', 'Øª', 'Ø', '®', 'Ø', '²', 'ÙĬ', 'ÙĨ', 'ĠÙĪ', 'Ø', '²', 'Ø§Ø', '¯', 'Øª', 'Ġ', 'Ø§', 'ÙĬ', 'Ø±', 'Ø§', 'ÙĨ', 'ĠØ§ÙĦ', 'Ø§', 'ÙĪ', 'ÙĨ', 'Ø©', 'ĠØ§ÙĦ', 'Ø§Ø', '®', 'ÙĬ', 'Ø±', 'Ø©', 'ĠÙĪ', 'Øª', 'ÙĬ', 'Ø±', 'Ø©', 'Ġ', 'Ø§', 'ÙĨ', 'Øª', 'Ùĩ', 'Ø§', 'Ù', 'ĥ', 'ĠØ', '¨', 'ÙĨ', 'ÙĪ', 'Ø¯', 'ĠØ§ÙĦ', 'Ø§Ø', 'ª', 'Ù', 'ģ', 'Ø§', 'Ù', 'Ĥ', 'ĠØ§ÙĦ', 'ÙĨ', 'ÙĪ', 'ÙĪ', 'ÙĬ', 'ĠØ§ÙĦ', 'Ø¯', 'ÙĪ', 'ÙĦ', 'ÙĬ', 'ĠØ§ÙĦ', 'Ùħ', 'ÙĪ', 'Ù', 'Ĥ', 'Ø¹', 'ĠØ', '¹', 'Ø§', 'Ùħ', 'ĠÙħ', 'Ø', 'Ń', 'Ø§', 'ÙĪ', 'ÙĦ', 'Ø©', 'ĠÙ', 'Ĭ', 'Ø¨', 'Ø¯', 'ÙĪ', 'Ġ', 'ÙĦ', 'ÙĦ', 'Ø', '¶', 'Ø', 'º', 'Ø', '·', 'ĠØ§ÙĦ', 'Ø±', 'ÙĬ', 'Ø³', 'ĠØ§ÙĦ', 'Ø§', 'Ùħ', 'Ø±', 'ÙĬ', 'Ù', 'ĥ', 'ÙĬ', 'ĠØ', '¬', 'ÙĪ', 'ĠØ', '¨', 'Ø§', 'ÙĬ', 'Ø¯', 'ÙĨ', 'Ġ', 'ÙĦ', 'ÙĦ', 'Ø¹', 'Ø¯', 'ÙĪ', 'ÙĦ', 'ĠÙ', 'Ĥ', 'Ø±', 'Ø§', 'Ø±', 'ĠØ', '³', 'ÙĦ', 'Ù', 'ģ', 'Ùĩ', 'ĠØ', '¯', 'ÙĪ', 'ÙĨ', 'Ø§ÙĦ', 'Ø¯', 'ĠØ', 'ª', 'Ø±', 'Ø§', 'Ùħ', 'Ø¨', 'ĠØ§ÙĦ', 'Ø§', 'ÙĨ', 'Ø³', 'Ø', 'Ń', 'Ø§Ø', '¨', 'ĠØ§ÙĦ', 'Ø§Ø', 'ª', 'Ù', 'ģ', 'Ø§', 'Ù', 'Ĥ', 'ĠÙĪ', 'Ø§ÙĦ', 'Ùħ', 'ÙĪ', 'Ø§Ø', '¬', 'Ùĩ', 'Ø©', 'ĠÙ', 'Ĥ', 'Ø§', 'Ùħ', 'Ø©', 'ĠØ§ÙĦ', 'Ø', '¬', 'Ø§', 'ÙĨ', 'Ø¨', 'ÙĬ', 'ÙĨ', 'ĠÙ', 'Ĭ', 'Ø', '¬', 'Ø¨', 'Ġ', 'Ø§', 'ÙĨ', 'ĠÙ', 'Ĭ', 'Ø¨', 'Ø§Ø', '¯', 'Ø±', 'ĠØ', '¨', 'Ø§ÙĦ', 'Øª', 'Ø', 'Ń', 'Ø±', 'Ù', 'ĥ', 'Ġ', 'ÙĦ', 'Ø§', 'ÙĨ', 'Ù', 'Ĥ', 'Ø§Ø', '°', 'ĠØ§ÙĦ', 'Ø§Ø', 'ª', 'Ù', 'ģ', 'Ø§', 'Ù', 'Ĥ', 'ĠÙ', 'ĥ', 'Ø§', 'ÙĨ', 'Øª', 'Ġ', 'Ø§', 'ÙĬ', 'Ø±', 'Ø§', 'ÙĨ', 'ĠÙĪ', 'Ø§', 'Ù', 'ģ', 'Ù', 'Ĥ', 'Øª', 'Ġ', 'Ø§Ø', 'º', 'ÙĦ', 'Ø§', 'Ù', 'Ĥ', 'ĠÙħ', 'Ù', 'ģ', 'Ø§Ø', '¹', 'ÙĦ', 'Ġ', 'Ø§', 'Ø±', 'Ø§', 'Ù', 'ĥ', 'ĠÙ', 'Ĭ', 'Ù', 'Ĥ', 'Ø¹', 'ĠÙ', 'ĥ', 'ÙĬ', 'ÙĦ', 'ÙĪ', 'Ùħ', 'Øª', 'Ø±', 'Ø§', 'ĠØ', '·', 'Ùĩ', 'Ø±', 'Ø§', 'ÙĨ', 'ĠØ', '¨', 'Ùħ', 'ÙĪ', 'Ø', '¬', 'Ø¨', 'Ġ', 'Ø§Ø', 'ª', 'Ù', 'ģ', 'Ø§', ' ...
# len(Tokenized) =  971
#
#
# Token IDs:  [12919, 22654, 26897, 12919, 23338, 17550, 103, 39848, 38843, 12919, 220, 34247, 106, 41486, 39848, 12919, 26897, 220, 12919, 23338, 148, 116, 25405, 45632, 28981, 41486, 39848, 26897, 22654, 38843, 47048, 149, 223, 34247, 117, 13862, 220, 12919, 26897, 12919, 149, 225, 45692, 41486, 148, 106, 41486, 39848, 26897, 220, 12919, 22654, 26897, 12919, 23338, 220, 12919, 23338, 148, 116, 25405, 45632, 28981, 41486, 39848, 26897, 22654, 38843, 47048, 149, 223, 34247, 117, 13862, 220, 12919, 26897, 12919, 149, 225, 28981, 23338, 30335, 30335, 22654, 17550, 103, 25405, 29519, 22654, 38843, 12919, 220, 13862, 41486, 148, 112, 148, 118, 22654, 13862, 29519, 17550, 101, 148, 112, 149, 225, 13862, 18923, 225, 12919, 25405, 13862, 28981, 44690, 12919, 25405, 220, 34247, 117, 13862, 23338, 41486, 47048, 23338, 148, 116, 25405, 45632, 28981, 148, 115, 12919, 149, 224, 45632, 28981, 148, 108, 26897, 22654, 45632, 28981, 12919, 22654, 26897, 12919, 23338, 22654, 45632, 28981, 22654, 30335, 25405, 28981, 148, 105, 25405, 44690, 45632, 42092, 23338, 149, 224, 13862, 41486, 42092, 45692, 23525, 220, 34247, 117, 13862, 12919, 25405, 28981, 25405, 41486, 148, 255, 38843, 148, 104, 17550, 101, 34247, 111, 25405, 28981, 25405, 23338, 148, 116, 25405, 45632, 17550, 101, 29519, 26897, 30335, 148, 110, 18923, 225, 25405, 23525, 30335, 23338, 38843, 22654, 18923, 224, 30335, 13862, 29519, 220, 12919, 23338, 220, 34247, 106, 41486, 39848, 12919, 26897, 28981, 41486, 39848, 26897, 22654, 38843, 18923, 232, 148, 112, 25405, 13862, 17550, 117, 34247, 107, 45632, 17550, 103, 148, 112, 148, 118, 22654, 13862, 220, 12919, 23338, 148, 116, 25405, 45632, 28981, 45692, 30335, 23525, 42092, 12919, 23338, 148, 116, 25405, 45632, 28981, 38843, 44690, 25405, 17550, 111, 22654, 149, 225, 30335, 23338, 220, 12919, 30335, 23525, 28981, 45692, 23338, 45632, 28981, 149, 223, 12919, 26897, 45692, 22654, 45632, 28981, 148, 105, 38843, 22654, 38843, 45632, 17550, 103, 39848, 38843, 12919, 18923, 232, 30335, 25405, 28981, 34247, 255, 38843, 28981, 25405, 149, 224, 39848, 13862, 42092, 149, 224, 23525, 18923, 225, 25405, 23525, 30335, 23338, 38843, 22654, 17550, 101, 25405, 44690, 23338, 22654, 220, 34247, 106, 26897, 17550, 255, 149, 224, 149, 224, 23338, 12919, 17550, 103, 149, 224, 38843, 25405, 12919, 28981, 44690, 25405, 13862, 17550, 101, 149, 224, 148, 115, 34247, 117, 34247, 103, 28981, 30335, 149, 224, 30335, 38843, 42092, 23525, 41486, 148, 106, 148, 110, 22654, 23338, 42092, 148, 110, 34247, 107, 41486, 220, 12919, 22654, 26897, 12919, 23338, 28981, 12919, 30335, 23338, 45632, 28981, 34247, 106, 22654, 26897, 45632, 42092, 41486, 22654, 26897, 45632, 220, 12919, 23338, 41486, 29519, 12919, 149, 225, 17550, 101, 23338, 30335, 38843, 28981, 34247, 103, 149, 223, 12919, 149, 224, 28981, 23338, 30335, 30335, 22654, 28981, 38843, 30335, 13862, 22654, 28981, 25405, 30335, 149, 224, 44690, 17550, 117, 12919, 25405, 47048, 148, 255, 12919, 30335, 13862, 45632, 18923, 232, 39848, 38843, 30335, 220, 13862, 13862, 148, 114, 148, 118, 148, 115, 28981, 26897, 22654, 45692, 28981, 12919, 25405, 26897, 22654, 149, 225, 22654, 17550, 105, 30335, 17550, 101, 12919, 22654, 38843, 23338, 220, 13862, 13862, 44690, 38843, 30335, 13862, 18923, 224, 26897, 12919, 26897, 17550, 111, 13862, 149, 223, 29519, 17550, 107, 30335, 23338, 23525, 38843, 17550, 103, 26897, 12919, 25405, 39848, 28981, 12919, 23338, 45692, 148, 255, 34247, 101, 28981, 34247, 103, 149, 223, 12919, 149, 224, 42092, 23525, 25405, 30335, 34247, 105, 29519, 45632, 18923, 224, 12919, 25405, 45632, 28981, 148, 105, 12919, 23338, 39848, 22654, 23338, 18923, 232, 148, 105, 39848, 220, 12919, 23338, 18923, 232, 39848, 34247, 107, 26897, 17550, 101, 23525, 41486, 148, 255, 26897, 149, 225, 220, 13862, 12919, 23338, 149, 224, 34247, 108, 28981, 34247, 103, 149, 223, 12919, 149, 224, 18923, 225, 12919, 23338, 41486, 220, 12919, 22654, 26897, 12919, 23338, 42092, 12919, 149, 223, 149, 224, 41486, 220, 34247, 118, 13862,  ...
# len(Token IDs) =  971

# %% [markdown]
# ### Input Formatting for GPT2

# %%
import logging

# Set logger to avoid warning `token indices sequence length is longer than the specified maximum sequence length for this model (1017 > 512)`
logging.getLogger("transformers.tokenization_utils").setLevel(logging.ERROR)


def text_to_id(tokenizer, text_list):
    """
    It is a function to transform text to id.
    # `encode` will:
    #   (1) Tokenize the sentence.
    #   (2) Prepend the `[CLS]` token to the start.
    #   (3) Append the `[SEP]` token to the end.
    #   (4) Map tokens to their IDs.
    """
    ids_list = []
    
    for item in text_list:
        # Sentence to id and add [CLS] and [SEP]
        encoded_item = tokenizer.encode(item, add_special_tokens=True)
        ids_list.append(encoded_item)
    
    return ids_list

# %%
for i in range(len(train_text)):
    if not isinstance(train_text[i], str):
        train_text[i] = str(train_text[i])

# %%
for i in range(len(test_text)):
    if not isinstance(test_text[i], str):
        test_text[i] = str(test_text[i])

# %%
train_text_ids = text_to_id(tokenizer, train_text)
test_text_ids = text_to_id(tokenizer, test_text)


# Print sentence 0, now as a list of IDs.
print('Original: {}\n'.format(train_text[0]))
print('Token IDs: {}\n'.format(train_text_ids[0]))
print("len(train_text_ids) = {}\n".format(len(train_text_ids)))
print("len(test_text_ids) = {}".format(len(test_text_ids)))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1404 > 1024). Running this sequence through the model will result in indexing errors
# Original: ايران تبدا اختبار انظمة التبريد مفاعل اراكستختبر ايران انظمة التبريد مفاعل اراك النووي تمهيدا لتشغيله بشكل كامل العام اعلنت منظمة الطاقة الذرية الايرانية اليوم الجمعة ونقلت وسال اعلام المتحدث باسم المنظمة بهروز كمالوندي قوله ان اختبار التبريد يشمل عادة تشغيل انظمة السوال وانظمة الدعم سيكون اوال السنة الفارسية الجديدة تبدا يوم الاحد المقبل وقال كمالوندي بمعني اخر حققنا تقدما العمل بقطاعات الوقود والتخزين وزادت ايران الاونة الاخيرة وتيرة انتهاك بنود الاتفاق النووي الدولي الموقع عام محاولة يبدو للضغط الريس الامريكي جو بايدن للعدول قرار سلفه دونالد ترامب الانسحاب الاتفاق والمواجهة قامة الجانبين يجب ان يبادر بالتحرك لانقاذ الاتفاق كانت ايران وافقت اغلاق مفاعل اراك يقع كيلومترا طهران بموجب اتفاق مسموحا بانتاج كمية محدودة الما الثقيل عملت اعادة تصميم المفاعل تقول انها تعتزم انتاج نظار لاغراض طبية وزراعية وقالت الوكالة الدولية للطاقة الذرية تقرير لدولها الاعضا الاسبوع ان ايران بدات تخصيب اليورانيوم محطة نطنز الارض باستخدام نوع ثان اجهزة الطرد المركزي المتقدمة اي ار انتهاك جديد للاتفاق
#
# Token IDs: [12919, 22654, 26897, 12919, 23338, 17550, 103, 39848, 38843, 12919, 220, 34247, 106, 41486, 39848, 12919, 26897, 220, 12919, 23338, 148, 116, 25405, 45632, 28981, 41486, 39848, 26897, 22654, 38843, 47048, 149, 223, 34247, 117, 13862, 220, 12919, 26897, 12919, 149, 225, 45692, 41486, 148, 106, 41486, 39848, 26897, 220, 12919, 22654, 26897, 12919, 23338, 220, 12919, 23338, 148, 116, 25405, 45632, 28981, 41486, 39848, 26897, 22654, 38843, 47048, 149, 223, 34247, 117, 13862, 220, 12919, 26897, 12919, 149, 225, 28981, 23338, 30335, 30335, 22654, 17550, 103, 25405, 29519, 22654, 38843, 12919, 220, 13862, 41486, 148, 112, 148, 118, 22654, 13862, 29519, 17550, 101, 148, 112, 149, 225, 13862, 18923, 225, 12919, 25405, 13862, 28981, 44690, 12919, 25405, 220, 34247, 117, 13862, 23338, 41486, 47048, 23338, 148, 116, 25405, 45632, 28981, 148, 115, 12919, 149, 224, 45632, 28981, 148, 108, 26897, 22654, 45632, 28981, 12919, 22654, 26897, 12919, 23338, 22654, 45632, 28981, 22654, 30335, 25405, 28981, 148, 105, 25405, 44690, 45632, 42092, 23338, 149, 224, 13862, 41486, 42092, 45692, 23525, 220, 34247, 117, 13862, 12919, 25405, 28981, 25405, 41486, 148, 255, 38843, 148, 104, 17550, 101, 34247, 111, 25405, 28981, 25405, 23338, 148, 116, 25405, 45632, 17550, 101, 29519, 26897, 30335, 148, 110, 18923, 225, 25405, 23525, 30335, 23338, 38843, 22654, 18923, 224, 30335, 13862, 29519, 220, 12919, 23338, 220, 34247, 106, 41486, 39848, 12919, 26897, 28981, 41486, 39848, 26897, 22654, 38843, 18923, 232, 148, 112, 25405, 13862, 17550, 117, 34247, 107, 45632, 17550, 103, 148, 112, 148, 118, 22654, 13862, 220, 12919, 23338, 148, 116, 25405, 45632, 28981, 45692, 30335, 23525, 42092, 12919, 23338, 148, 116, 25405, 45632, 28981, 38843, 44690, 25405, 17550, 111, 22654, 149, 225, 30335, 23338, 220, 12919, 30335, 23525, 28981, 45692, 23338, 45632, 28981, 149, 223, 12919, 26897, 45692, 22654, 45632, 28981, 148, 105, 38843, 22654, 38843, 45632, 17550, 103, 39848, 38843, 12919, 18923, 232, 30335, 25405, 28981, 34247, 255, 38843, 28981, 25405, 149, 224, 39848, 13862, 42092, 149, 224, 23525, 18923, 225, 25405, 23525, 30335, 23338, 38843, 22654, 17550, 101, 25405, 44690, 23338, 22654, 220, 34247, 106, 26897, 17550, 255, 149, 224, 149, 224, 23338, 12919, 17550, 103, 149, 224, 38843, 25405, 12919, 28981, 44690, 25405, 13862, 17550, 101, 149, 224, 148, 115, 34247, 117, 34247, 103, 28981, 30335, 149, 224, 30335, 38843, 42092, 23525, 41486, 148, 106, 148, 110, 22654, 23338, 42092, 148, 110, 34247, 107, 41486, 220, 12919, 22654, 26897, 12919, 23338, 28981, 12919, 30335, 23338, 45632, 28981, 34247, 106, 22654, 26897, 45632, 42092, 41486, 22654, 26897, 45632, 220, 12919, 23338, 41486, 29519, 12919, 149, 225, 17550, 101, 23338, 30335, 38843, 28981, 34247, 103, 149, 223, 12919, 149, 224, 28981, 23338, 30335, 30335, 22654, 28981, 38843, 30335, 13862, 22654, 28981, 25405, 30335, 149, 224, 44690, 17550, 117, 12919, 25405, 47048, 148, 255, 12919, 30335, 13862, 45632, 18923, 232, 39848, 38843, 30335, 220, 13862, 13862, 148, 114, 148, 118, 148, 115, 28981, 26897, 22654, 45692, 28981, 12919, 25405, 26897, 22654, 149, 225, 22654, 17550, 105, 30335, 17550, 101, 12919, 22654, 38843, 23338, 220, 13862, 13862, 44690, 38843, 30335, 13862, 18923, 224, 26897, 12919, 26897, 17550, 111, 13862, 149, 223, 29519, 17550, 107, 30335, 23338, 23525, 38843, 17550, 103, 26897, 12919, 25405, 39848, 28981, 12919, 23338, 45692, 148, 255, 34247, 101, 28981, 34247, 103, 149, 223, 12919, 149, 224, 42092, 23525, 25405, 30335, 34247, 105, 29519, 45632, 18923, 224, 12919, 25405, 45632, 28981, 148, 105, 12919, 23338, 39848, 22654, 23338, 18923, 232, 148, 105, 39848, 220, 12919, 23338, 18923, 232, 39848, 34247, 107, 26897, 17550, 101, 23525, 41486, 148, 255, 26897, 149, 225, 220, 13862, 12919, 23338, 149, 224, 34247, 108, 28981, 34247, 103, 149, 223, 12919, 149, 224, 18923, 225, 12919, 23338, 41486, 220, 12919, 22654, 26897, 12919, 23338, 42092, 12919, 149, 223, 149, 224, 41486, 220, 34247, 118, 13862, 1 ...
#
# len(train_text_ids) = 64000
#
# len(test_text_ids) = 16000

# %%
print('Train: max sentence length: ', max([len(sen) for sen in train_text_ids]))
print('Train: Min sentence length: ', min([len(sen) for sen in train_text_ids]))
print('Test: max sentence length: ', max([len(sen) for sen in test_text_ids]))
print('Test: Min sentence length: ', min([len(sen) for sen in test_text_ids]))
# Out:
# Train: max sentence length:  87621
# Train: Min sentence length:  46
# Test: max sentence length:  40514
# Test: Min sentence length:  59

# %% [markdown]
# ### Padding & Truncating

# %%
def padding_truncating(input_ids_list, max_length):
    """
    It is a function to perform padding and truncating
    @param input_ids_list: <List> text_ids
    @param max_length: <Integer> the number we wanna the sentence to be padding or truncating
    @return: processed input_ids_list
    """
    processed_input_ids_list = []
    for item in input_ids_list:
        seq_list = []
        
        if len(item) < max_length:
            # Define a seq_list with the length of max_length
            seq_list = [0] * (max_length - len(item))
            item = item + seq_list
        
        elif len(item) >= max_length:
            item = item[:max_length]
            
        processed_input_ids_list.append(item)
    
    return processed_input_ids_list

# %%
train_padding_list = padding_truncating(train_text_ids, max_length=50)
test_padding_list = padding_truncating(test_text_ids, max_length=50)

# %% [markdown]
# ### Attention Masks

# %%
def get_attention_masks(pad_input_ids_list):
    """
    It is a function to get attention masks:
    
    - If a token ID is 0, then it's padding, set the mask to 0.
    - If a token ID is > 0, then it's a real token, set the mask to 1.
    """
    attention_masks_list = []
    
    for item in pad_input_ids_list:
        
        mask_list = []
        for subitem in item:
            if subitem > 0:
                mask_list.append(1)
            else:
                mask_list.append(0)
        attention_masks_list.append(mask_list)
    
    return attention_masks_list

# %%
train_attention_masks = get_attention_masks(train_padding_list)
test_attention_masks = get_attention_masks(test_padding_list)

assert len(train_text) == len(train_labels) == len(train_attention_masks) == len(train_padding_list), "Training data length mismatch"
assert len(test_text) == len(test_labels) == len(test_attention_masks) == len(test_padding_list), "Testing data length mismatch"

# %%
print(len(train_text), len(train_labels), len(train_attention_masks), len(train_padding_list))
# Out:
# 64000 64000 64000 64000

# %% [markdown]
# ### Split train dataset into train_dataset and validation_dataset

# %%
from sklearn.model_selection import train_test_split

# Use 90% for training and 10% for validation.
train_padding_list, validation_padding_list, train_labels, validation_labels, train_attention_masks, validation_attention_masks = train_test_split(train_padding_list, train_labels, train_attention_masks, random_state=2020, test_size=0.1)

# %%
assert len(train_labels) == len(train_attention_masks) == len(train_padding_list)
assert len(validation_labels) == len(validation_attention_masks) == len(validation_padding_list)
assert len(test_labels) == len(test_attention_masks) == len(test_padding_list)

# %%
print("len(train_labels) = {}\nlen(validation_labels) = {}\nlen(test_labels) = {}".format(len(train_labels), len(validation_labels), len(test_labels)))
# Out:
# len(train_labels) = 57600
# len(validation_labels) = 6400
# len(test_labels) = 16000

# %% [markdown]
# ### Convert to Dataset

# %% [markdown]
# Convert all the List objects to tensor

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# Convert all inputs and labels into torch tensors, the required datatype for our model.
train_inputs = torch.tensor(train_padding_list)
validation_inputs = torch.tensor(validation_padding_list)
test_inputs = torch.tensor(test_padding_list)

train_labels = torch.tensor(train_labels)
validation_labels = torch.tensor(validation_labels)
test_labels = torch.tensor(test_labels)

train_masks = torch.tensor(train_attention_masks)
validation_masks = torch.tensor(validation_attention_masks)
test_masks = torch.tensor(test_attention_masks)

# %% [markdown]
# Form the Dataset with torch.tensor

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

# The DataLoader needs to know our batch size for training, so we specify it 
# here.
# For fine-tuning BERT on a specific task, the authors recommend a batch size of 16 or 32.

batch_size = 16

# Create the DataLoader for our training set.
train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

# Create the DataLoader for our validation set.
validation_data = TensorDataset(validation_inputs, validation_masks, validation_labels)
validation_sampler = RandomSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

# Create the DataLoader for our test set.
test_data = TensorDataset(test_inputs, test_masks, test_labels)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

# %% [markdown]
# ## Train GPT2 Text Classification Model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Get the actual model.
print('Loading model...')
model = GPT2ForSequenceClassification.from_pretrained(pretrained_model_name_or_path=model_name_or_path, config=model_config)

# resize model embedding to match new tokenizer
model.resize_token_embeddings(len(tokenizer))

# fix model padding token id
model.config.pad_token_id = model.config.eos_token_id

# Load model to defined device.
model.to(device)
print('Model loaded to `%s`'%device)
# Out:
# Loading model...
# Downloading pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model loaded to `cuda`

# %% [markdown]
# ### Optimizer & Learning Rate Scheduler

# %%
# Note: AdamW is a class from the huggingface library (as opposed to pytorch) 
# I believe the 'W' stands for 'Weight Decay fix"
optimizer = AdamW(model.parameters(),
                  lr = 5e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from transformers import get_linear_schedule_with_warmup

# Number of training epochs (authors recommend between 2 and 4)
epochs = 4

# Total number of training steps is number of batches * number of epochs.
total_steps = len(train_dataloader) * epochs
print("total_steps = {}".format(total_steps))

# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)
# Out:
# total_steps = 14400

# %% [markdown]
# ### Train

# %%
import numpy as np

# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import random

# Set the seed value all over the place to make this reproducible.
seed_val = 12345

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)

# Store the average loss after each epoch so we can plot them.
loss_values = []

# For each epoch...
for epoch_i in range(epochs):
    
    ##########################################
    #               Training                 #
    ##########################################
    
    # Perform one full pass over the training set.

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # Measure how long the training epoch takes.
    t0 = time.time()

    # Reset the total loss for this epoch.
    total_loss = 0

    # Put the model into training mode. Don't be mislead--the call to 
    # `train` just changes the *mode*, it doesn't *perform* the training.
    # `dropout` and `batchnorm` layers behave differently during training
    # vs. test (source: https://stackoverflow.com/questions/51433378/what-does-model-train-do-in-pytorch)
    model.train()

    # For each batch of training data...
    for step, batch in enumerate(train_dataloader):

        # Progress update every 10 batches.
        if step % 10 == 0 and not step == 0:
            # Calculate elapsed time in minutes.
            elapsed = format_time(time.time() - t0)
            
            # Report progress.
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        # Unpack this training batch from our dataloader. 
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        # Clear the gradients.
        model.zero_grad()        

        # Perform a forward pass (evaluate the model on this training batch).
        # This will return the loss (rather than the model output) because we have provided the `labels`.
        outputs = model(b_input_ids, 
                        token_type_ids=None, 
                        attention_mask=b_input_mask, 
                        labels=b_labels)
        
        # The call to `model` always returns a tuple, so we need to pull the 
        # loss value out of the tuple.
        loss = outputs[0]

        # Accumulate the training loss over all of the batches so that we can calculate the average loss at the end. 
        # `loss` is a Tensor containing a single value; the `.item()` function just returns the Python value from the tensor.
        total_loss += loss.item()

        # Perform a `backward` pass to calculate the gradients.
        loss.backward()

        # Clip the norm of the gradients to 1.0.
        # This is to help prevent the "exploding gradients" problem.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step using the computed gradient.
        # The optimizer dictates the "update rule"--how the parameters are modified based on their gradients, the learning rate, etc.
        optimizer.step()

        # Update the learning rate.
        scheduler.step()

    # Calculate the average loss over the training data.
    avg_train_loss = total_loss / len(train_dataloader)            
    
    # Store the loss value for plotting the learning curve.
    loss_values.append(avg_train_loss)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(format_time(time.time() - t0)))
        
        
    ##########################################
    #               Validation               #
    ##########################################
    # After the completion of each training epoch, measure our performance on our validation set.

    print("")
    print("Running Validation...")

    t0 = time.time()

    # Put the model in evaluation mode--the dropout layers behave differently during evaluation.
    model.eval()

    # Tracking variables 
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0

    # Evaluate data for one epoch
    for batch in validation_dataloader:
        
        # Add batch to device
        batch = tuple(t.to(device) for t in batch)
        
        # Unpack the inputs from our dataloader
        b_input_ids, b_input_mask, b_labels = batch
        
        # Telling the model not to compute or store gradients, saving memory and speeding up validation
        with torch.no_grad():        

            # Forward pass, calculate logit predictions.
            # This will return the logits rather than the loss because we have not provided labels.
            # token_type_ids is the same as the "segment ids", which differentiates sentence 1 and 2 in 2-sentence tasks.
            # The documentation for this `model` function is here: 
            # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
            outputs = model(b_input_ids, 
                            token_type_ids=None, 
                            attention_mask=b_input_mask)
        
        # Get the "logits" output by the model. The "logits" are the output
        # values prior to applying an activation function like the softmax.
        logits = outputs[0]

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        
        # Calculate the accuracy for this batch of test sentences.
        # flat_accuracy(y_pred, y_true)
        tmp_eval_accuracy = flat_accuracy(logits, label_ids)
        
        # Accumulate the total accuracy.
        eval_accuracy += tmp_eval_accuracy

        # Track the number of batches
        nb_eval_steps += 1

    # Report the final accuracy for this validation run.
    print("  Accuracy: {0:.2f}".format(eval_accuracy/nb_eval_steps))
    print("  Validation took: {:}".format(format_time(time.time() - t0)))

print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 4 ========
# Training...
#   Batch    10  of  3,600.    Elapsed: 0:00:04.
#   Batch    20  of  3,600.    Elapsed: 0:00:06.
#   Batch    30  of  3,600.    Elapsed: 0:00:08.
#   Batch    40  of  3,600.    Elapsed: 0:00:09.
#   Batch    50  of  3,600.    Elapsed: 0:00:11.
#   Batch    60  of  3,600.    Elapsed: 0:00:13.
#   Batch    70  of  3,600.    Elapsed: 0:00:14.
#   Batch    80  of  3,600.    Elapsed: 0:00:16.
#   Batch    90  of  3,600.    Elapsed: 0:00:18.
#   Batch   100  of  3,600.    Elapsed: 0:00:19.
#   Batch   110  of  3,600.    Elapsed: 0:00:21.
#   Batch   120  of  3,600.    Elapsed: 0:00:23.
#   Batch   130  of  3,600.    Elapsed: 0:00:24.
#   Batch   140  of  3,600.    Elapsed: 0:00:26.
#   Batch   150  of  3,600.    Elapsed: 0:00:28.
#   Batch   160  of  3,600.    Elapsed: 0:00:29.
#   Batch   170  of  3,600.    Elapsed: 0:00:31.
#   Batch   180  of  3,600.    Elapsed: 0:00:33.
#   Batch   190  of  3,600.    Elapsed: 0:00:34.
#   Batch   200  of  3,600.    Elapsed: 0:00:36.
#   Batch   210  of  3,600.    Elapsed: 0:00:38.
#   Batch   220  of  3,600.    Elapsed: 0:00:40.
#   Batch   230  of  3,600.    Elapsed: 0:00:41.
#   Batch   240  of  3,600.    Elapsed: 0:00:43.
#   Batch   250  of  3,600.    Elapsed: 0:00:45.
#   Batch   260  of  3,600.    Elapsed: 0:00:46.
#   Batch   270  of  3,600.    Elapsed: 0:00:48.
#   Batch   280  of  3,600.    Elapsed: 0:00:50.
#   Batch   290  of  3,600.    Elapsed: 0:00:52.
#   Batch   300  of  3,600.    Elapsed: 0:00:53.
#   Batch   310  of  3,600.    Elapsed: 0:00:55.
#   Batch   320  of  3,600.    Elapsed: 0:00:57.
#   Batch   330  of  3,600.    Elapsed: 0:00:58.
#   Batch   340  of  3,600.    Elapsed: 0:01:00.
#   Batch   350  of  3,600.    Elapsed: 0:01:02.
#   Batch   360  of  3,600.    Elapsed: 0:01:04.
#   Batch   370  of  3,600.    Elapsed: 0:01:05.
#   Batch   380  of  3,600.    Elapsed: 0:01:07.
#   Batch   390  of  3,600.    Elapsed: 0:01:09.
#   Batch   400  of  3,600.    Elapsed: 0:01:11.
#   Batch   410  of  3,600.    Elapsed: 0:01:12.
#   Batch   420  of  3,600.    Elapsed: 0:01:14.
#   Batch   430  of  3,600.    Elapsed: 0:01:16.
#   Batch   440  of  3,600.    Elapsed: 0:01:18.
#   Batch   450  of  3,600.    Elapsed: 0:01:19.
#   Batch   460  of  3,600.    Elapsed: 0:01:21.
#   Batch   470  of  3,600.    Elapsed: 0:01:23.
#   Batch   480  of  3,600.    Elapsed: 0:01:25.
#   Batch   490  of  3,600.    Elapsed: 0:01:27.
#   Batch   500  of  3,600.    Elapsed: 0:01:28.
#   Batch   510  of  3,600.    Elapsed: 0:01:30.
#   Batch   520  of  3,600.    Elapsed: 0:01:32.
#   Batch   530  of  3,600.    Elapsed: 0:01:34.
#   Batch   540  of  3,600.    Elapsed: 0:01:35.
#   Batch   550  of  3,600.    Elapsed: 0:01:37.
#   Batch   560  of  3,600.    Elapsed: 0:01:39.
#   Batch   570  of  3,600.    Elapsed: 0:01:41.
#   Batch   580  of  3,600.    Elapsed: 0:01:43.
#   Batch   590  of  3,600.    Elapsed: 0:01:44.
#   Batch   600  of  3,600.    Elapsed: 0:01:46.
#   Batch   610  of  3,600.    Elapsed: 0:01:48.
#   Batch   620  of  3,600.    Elapsed: 0:01:50.
#   Batch   630  of  3,600.    Elapsed: 0:01:52.
#   Batch   640  of  3,600.    Elapsed: 0:01:53.
#   Batch   650  of  3,600.    Elapsed: 0:01:55.
#   Batch   660  of  3,600.    Elapsed: 0:01:57.
#   Batch   670  of  3,600.    Elapsed: 0:01:59.
#   Batch   680  of  3,600.    Elapsed: 0:02:00.
#   Batch   690  of  3,600.    Elapsed: 0:02:02.
#   Batch   700  of  3,600.    Elapsed: 0:02:04.
#   Batch   710  of  3,600.    Elapsed: 0:02:06.
#   Batch   720  of  3,600.    Elapsed: 0:02:08.
#   Batch   730  of  3,600.    Elapsed: 0:02:09.
#   Batch   740  of  3,600.    Elapsed: 0:02:11.
#   Batch   750  of  3,600.    Elapsed: 0:02:13.
#   Batch   760  of  3,600.    Elapsed: 0:02:15.
#   Batch   770  of  3,600.    Elapsed: 0:02:16.
#   Batch   780  of  3,600.    Elapsed: 0:02:18.
#   Batch   790  of  3,600.    Elapsed: 0:02:20.
#   Batch   800  of  3,600.    Elapsed: 0:02:22.
#   Batch   810  of  3,600.    Elapsed: 0:02:24.
#   Batch   820  of  3,600.    Elapsed: 0:02:25.
#   Batch   830  of  3,600.    Elapsed: 0:02:27.
#   Batch   840  of  3,600.    Elapsed: 0:02:29.
#   Batch   850  of  3,600.    Elapsed: 0:02:31.
#   Batch   860  of  3,600.    Elapsed: 0:02:32.
#   Batch   870  of  3,600.    Elapsed: 0:02:34.
#   Batch   880  of  3,600.    Elapsed: 0:02:36.
#   Batch   890  of  3,600.    Elapsed: 0:02:38.
#   Batch   900  of  3,600.    Elapsed: 0:02:40.
#   Batch   910  of  3,600.    Elapsed: 0:02:41.
#   Batch   920  of  3,600.    Elapsed: 0:02:43.
#   Batch   930  of  3,600.    Elapsed: 0:02:45.
#   Batch   940  of  3,600.    Elapsed: 0:02:47.
#   Batch   950  of  3,600.    Elapsed: 0:02:48.
#   Batch   960  of  3,600.    Elapsed: 0:02:50.
#   Batch   970  of  3,600.    Elapsed: 0:02:52.
#   Batch   980  of  3,600.    Elapsed: 0:02:54.
#   Batch   990  of  3,600.    Elapsed: 0:02:55.
#   Batch 1,000  of  3,600.    Elapsed: 0:02:57.
#   Batch 1,010  of  3,600.    Elapsed: 0:02:59.
#   Batch 1,020  of  3,600.    Elapsed: 0:03:01.
#   Batch 1,030  of  3,600.    Elapsed: 0:03:03.
#   Batch 1,040  of  3,600.    Elapsed: 0:03:04.
#   Batch 1,050  of  3,600.    Elapsed: 0:03:06.
#   Batch 1,060  of  3,600.    Elapsed: 0:03:08.
#   Batch 1,070  of  3,600.    Elapsed: 0:03:10.
#   Batch 1,080  of  3,600.    Elapsed: 0:03:11.
#   Batch 1,090  of  3,600.    Elapsed: 0:03:13.
#   Batch 1,100  of  3,600.    Elapsed: 0:03:15.
#   Batch 1,110  of  3,600.    Elapsed: 0:03:17.
#   Batch 1,120  of  3,600.    Elapsed: 0:03:19.
#   Batch 1,130  of  3,600.    Elapsed: 0:03:20.
#   Batch 1,140  of  3,600.    Elapsed: 0:03:22.
#   Batch 1,150  of  3,600.    Elapsed: 0:03:24.
#   Batch 1,160  of  3,600.    Elapsed: 0:03:26.
#   Batch 1,170  of  3,600.    Elapsed: 0:03:27.
#   Batch 1,180  of  3,600.    Elapsed: 0:03:29.
#   Batch 1,190  of  3,600.    Elapsed: 0:03:31.
#   Batch 1,200  of  3,600.    Elapsed: 0:03:33.
#   Batch 1,210  of  3,600.    Elapsed: 0:03:35.
#   Batch 1,220  of  3,600.    Elapsed: 0:03:36.
#   Batch 1,230  of  3,600.    Elapsed: 0:03:38.
#   Batch 1,240  of  3,600.    Elapsed: 0:03:40.
#   Batch 1,250  of  3,600.    Elapsed: 0:03:42.
#   Batch 1,260  of  3,600.    Elapsed: 0:03:44.
#   Batch 1,270  of  3,600.    Elapsed: 0:03:45.
#   Batch 1,280  of  3,600.    Elapsed: 0:03:47.
#   Batch 1,290  of  3,600.    Elapsed: 0:03:49.
#   Batch 1,300  of  3,600.    Elapsed: 0:03:51.
#   Batch 1,310  of  3,600.    Elapsed: 0:03:52.
#   Batch 1,320  of  3,600.    Elapsed: 0:03:54.
#   Batch 1,330  of  3,600.    Elapsed: 0:03:56.
#   Batch 1,340  of  3,600.    Elapsed: 0:03:58.
#   Batch 1,350  of  3,600.    Elapsed: 0:04:00.
#   Batch 1,360  of  3,600.    Elapsed: 0:04:01.
#   Batch 1,370  of  3,600.    Elapsed: 0:04:03.
#   Batch 1,380  of  3,600.    Elapsed: 0:04:05.
#   Batch 1,390  of  3,600.    Elapsed: 0:04:07.
#   Batch 1,400  of  3,600.    Elapsed: 0:04:08.
#   Batch 1,410  of  3,600.    Elapsed: 0:04:10.
#   Batch 1,420  of  3,600.    Elapsed: 0:04:12.
#   Batch 1,430  of  3,600.    Elapsed: 0:04:14.
#   Batch 1,440  of  3,600.    Elapsed: 0:04:15.
#   Batch 1,450  of  3,600.    Elapsed: 0:04:17.
#   Batch 1,460  of  3,600.    Elapsed: 0:04:19.
#   Batch 1,470  of  3,600.    Elapsed: 0:04:21.
#   Batch 1,480  of  3,600.    Elapsed: 0:04:23.
#   Batch 1,490  of  3,600.    Elapsed: 0:04:24.
#   Batch 1,500  of  3,600.    Elapsed: 0:04:26.
#   Batch 1,510  of  3,600.    Elapsed: 0:04:28.
#   Batch 1,520  of  3,600.    Elapsed: 0:04:30.
#   Batch 1,530  of  3,600.    Elapsed: 0:04:32.
#   Batch 1,540  of  3,600.    Elapsed: 0:04:33.
#   Batch 1,550  of  3,600.    Elapsed: 0:04:35.
#   Batch 1,560  of  3,600.    Elapsed: 0:04:37.
#   Batch 1,570  of  3,600.    Elapsed: 0:04:39.
#   Batch 1,580  of  3,600.    Elapsed: 0:04:40.
#   Batch 1,590  of  3,600.    Elapsed: 0:04:42.
#   Batch 1,600  of  3,600.    Elapsed: 0:04:44.
#   Batch 1,610  of  3,600.    Elapsed: 0:04:46.
#   Batch 1,620  of  3,600.    Elapsed: 0:04:48.
#   Batch 1,630  of  3,600.    Elapsed: 0:04:49.
#   Batch 1,640  of  3,600.    Elapsed: 0:04:51.
#   Batch 1,650  of  3,600.    Elapsed: 0:04:53.
#   Batch 1,660  of  3,600.    Elapsed: 0:04:55.
#   Batch 1,670  of  3,600.    Elapsed: 0:04:56.
#   Batch 1,680  of  3,600.    Elapsed: 0:04:58.
#   Batch 1,690  of  3,600.    Elapsed: 0:05:00.
#   Batch 1,700  of  3,600.    Elapsed: 0:05:02.
#   Batch 1,710  of  3,600.    Elapsed: 0:05:04.
#   Batch 1,720  of  3,600.    Elapsed: 0:05:05.
#   Batch 1,730  of  3,600.    Elapsed: 0:05:07.
#   Batch 1,740  of  3,600.    Elapsed: 0:05:09.
#   Batch 1,750  of  3,600.    Elapsed: 0:05:11.
#   Batch 1,760  of  3,600.    Elapsed: 0:05:12.
#   Batch 1,770  of  3,600.    Elapsed: 0:05:14.
#   Batch 1,780  of  3,600.    Elapsed: 0:05:16.
#   Batch 1,790  of  3,600.    Elapsed: 0:05:18.
#   Batch 1,800  of  3,600.    Elapsed: 0:05:20.
#   Batch 1,810  of  3,600.    Elapsed: 0:05:21.
#   Batch 1,820  of  3,600.    Elapsed: 0:05:23.
#   Batch 1,830  of  3,600.    Elapsed: 0:05:25.
#   Batch 1,840  of  3,600.    Elapsed: 0:05:27.
#   Batch 1,850  of  3,600.    Elapsed: 0:05:28.
#   Batch 1,860  of  3,600.    Elapsed: 0:05:30.
#   Batch 1,870  of  3,600.    Elapsed: 0:05:32.
#   Batch 1,880  of  3,600.    Elapsed: 0:05:34.
#   Batch 1,890  of  3,600.    Elapsed: 0:05:36.
#   Batch 1,900  of  3,600.    Elapsed: 0:05:37.
#   Batch 1,910  of  3,600.    Elapsed: 0:05:39.
#   Batch 1,920  of  3,600.    Elapsed: 0:05:41.
#   Batch 1,930  of  3,600.    Elapsed: 0:05:43.
#   Batch 1,940  of  3,600.    Elapsed: 0:05:44.
#   Batch 1,950  of  3,600.    Elapsed: 0:05:46.
#   Batch 1,960  of  3,600.    Elapsed: 0:05:48.
#   Batch 1,970  of  3,600.    Elapsed: 0:05:50.
#   Batch 1,980  of  3,600.    Elapsed: 0:05:52.
#   Batch 1,990  of  3,600.    Elapsed: 0:05:53.
#   Batch 2,000  of  3,600.    Elapsed: 0:05:55.
#   Batch 2,010  of  3,600.    Elapsed: 0:05:57.
#   Batch 2,020  of  3,600.    Elapsed: 0:05:59.
#   Batch 2,030  of  3,600.    Elapsed: 0:06:00.
#   Batch 2,040  of  3,600.    Elapsed: 0:06:02.
#   Batch 2,050  of  3,600.    Elapsed: 0:06:04.
#   Batch 2,060  of  3,600.    Elapsed: 0:06:06.
#   Batch 2,070  of  3,600.    Elapsed: 0:06:08.
#   Batch 2,080  of  3,600.    Elapsed: 0:06:09.
#   Batch 2,090  of  3,600.    Elapsed: 0:06:11.
#   Batch 2,100  of  3,600.    Elapsed: 0:06:13.
#   Batch 2,110  of  3,600.    Elapsed: 0:06:15.
#   Batch 2,120  of  3,600.    Elapsed: 0:06:16.
#   Batch 2,130  of  3,600.    Elapsed: 0:06:18.
#   Batch 2,140  of  3,600.    Elapsed: 0:06:20.
#   Batch 2,150  of  3,600.    Elapsed: 0:06:22.
#   Batch 2,160  of  3,600.    Elapsed: 0:06:24.
#   Batch 2,170  of  3,600.    Elapsed: 0:06:25.
#   Batch 2,180  of  3,600.    Elapsed: 0:06:27.
#   Batch 2,190  of  3,600.    Elapsed: 0:06:29.
#   Batch 2,200  of  3,600.    Elapsed: 0:06:31.
#   Batch 2,210  of  3,600.    Elapsed: 0:06:32.
#   Batch 2,220  of  3,600.    Elapsed: 0:06:34.
#   Batch 2,230  of  3,600.    Elapsed: 0:06:36.
#   Batch 2,240  of  3,600.    Elapsed: 0:06:38.
#   Batch 2,250  of  3,600.    Elapsed: 0:06:40.
#   Batch 2,260  of  3,600.    Elapsed: 0:06:41.
#   Batch 2,270  of  3,600.    Elapsed: 0:06:43.
#   Batch 2,280  of  3,600.    Elapsed: 0:06:45.
#   Batch 2,290  of  3,600.    Elapsed: 0:06:47.
#   Batch 2,300  of  3,600.    Elapsed: 0:06:48.
#   Batch 2,310  of  3,600.    Elapsed: 0:06:50.
#   Batch 2,320  of  3,600.    Elapsed: 0:06:52.
#   Batch 2,330  of  3,600.    Elapsed: 0:06:54.
#   Batch 2,340  of  3,600.    Elapsed: 0:06:56.
#   Batch 2,350  of  3,600.    Elapsed: 0:06:57.
#   Batch 2,360  of  3,600.    Elapsed: 0:06:59.
#   Batch 2,370  of  3,600.    Elapsed: 0:07:01.
#   Batch 2,380  of  3,600.    Elapsed: 0:07:03.
#   Batch 2,390  of  3,600.    Elapsed: 0:07:04.
#   Batch 2,400  of  3,600.    Elapsed: 0:07:06.
#   Batch 2,410  of  3,600.    Elapsed: 0:07:08.
#   Batch 2,420  of  3,600.    Elapsed: 0:07:10.
#   Batch 2,430  of  3,600.    Elapsed: 0:07:12.
#   Batch 2,440  of  3,600.    Elapsed: 0:07:13.
#   Batch 2,450  of  3,600.    Elapsed: 0:07:15.
#   Batch 2,460  of  3,600.    Elapsed: 0:07:17.
#   Batch 2,470  of  3,600.    Elapsed: 0:07:19.
#   Batch 2,480  of  3,600.    Elapsed: 0:07:20.
#   Batch 2,490  of  3,600.    Elapsed: 0:07:22.
#   Batch 2,500  of  3,600.    Elapsed: 0:07:24.
#   Batch 2,510  of  3,600.    Elapsed: 0:07:26.
#   Batch 2,520  of  3,600.    Elapsed: 0:07:28.
#   Batch 2,530  of  3,600.    Elapsed: 0:07:29.
#   Batch 2,540  of  3,600.    Elapsed: 0:07:31.
#   Batch 2,550  of  3,600.    Elapsed: 0:07:33.
#   Batch 2,560  of  3,600.    Elapsed: 0:07:35.
#   Batch 2,570  of  3,600.    Elapsed: 0:07:36.
#   Batch 2,580  of  3,600.    Elapsed: 0:07:38.
#   Batch 2,590  of  3,600.    Elapsed: 0:07:40.
#   Batch 2,600  of  3,600.    Elapsed: 0:07:42.
#   Batch 2,610  of  3,600.    Elapsed: 0:07:44.
#   Batch 2,620  of  3,600.    Elapsed: 0:07:45.
#   Batch 2,630  of  3,600.    Elapsed: 0:07:47.
#   Batch 2,640  of  3,600.    Elapsed: 0:07:49.
#   Batch 2,650  of  3,600.    Elapsed: 0:07:51.
#   Batch 2,660  of  3,600.    Elapsed: 0:07:52.
#   Batch 2,670  of  3,600.    Elapsed: 0:07:54.
#   Batch 2,680  of  3,600.    Elapsed: 0:07:56.
#   Batch 2,690  of  3,600.    Elapsed: 0:07:58.
#   Batch 2,700  of  3,600.    Elapsed: 0:08:00.
#   Batch 2,710  of  3,600.    Elapsed: 0:08:01.
#   Batch 2,720  of  3,600.    Elapsed: 0:08:03.
#   Batch 2,730  of  3,600.    Elapsed: 0:08:05.
#   Batch 2,740  of  3,600.    Elapsed: 0:08:07.
#   Batch 2,750  of  3,600.    Elapsed: 0:08:08.
#   Batch 2,760  of  3,600.    Elapsed: 0:08:10.
#   Batch 2,770  of  3,600.    Elapsed: 0:08:12.
#   Batch 2,780  of  3,600.    Elapsed: 0:08:14.
#   Batch 2,790  of  3,600.    Elapsed: 0:08:16.
#   Batch 2,800  of  3,600.    Elapsed: 0:08:17.
#   Batch 2,810  of  3,600.    Elapsed: 0:08:19.
#   Batch 2,820  of  3,600.    Elapsed: 0:08:21.
#   Batch 2,830  of  3,600.    Elapsed: 0:08:23.
#   Batch 2,840  of  3,600.    Elapsed: 0:08:24.
#   Batch 2,850  of  3,600.    Elapsed: 0:08:26.
#   Batch 2,860  of  3,600.    Elapsed: 0:08:28.
#   Batch 2,870  of  3,600.    Elapsed: 0:08:30.
#   Batch 2,880  of  3,600.    Elapsed: 0:08:32.
#   Batch 2,890  of  3,600.    Elapsed: 0:08:33.
#   Batch 2,900  of  3,600.    Elapsed: 0:08:35.
#   Batch 2,910  of  3,600.    Elapsed: 0:08:37.
#   Batch 2,920  of  3,600.    Elapsed: 0:08:39.
#   Batch 2,930  of  3,600.    Elapsed: 0:08:40.
#   Batch 2,940  of  3,600.    Elapsed: 0:08:42.
#   Batch 2,950  of  3,600.    Elapsed: 0:08:44.
#   Batch 2,960  of  3,600.    Elapsed: 0:08:46.
#   Batch 2,970  of  3,600.    Elapsed: 0:08:48.
#   Batch 2,980  of  3,600.    Elapsed: 0:08:49.
#   Batch 2,990  of  3,600.    Elapsed: 0:08:51.
#   Batch 3,000  of  3,600.    Elapsed: 0:08:53.
#   Batch 3,010  of  3,600.    Elapsed: 0:08:55.
#   Batch 3,020  of  3,600.    Elapsed: 0:08:56.
#   Batch 3,030  of  3,600.    Elapsed: 0:08:58.
#   Batch 3,040  of  3,600.    Elapsed: 0:09:00.
#   Batch 3,050  of  3,600.    Elapsed: 0:09:02.
#   Batch 3,060  of  3,600.    Elapsed: 0:09:04.
#   Batch 3,070  of  3,600.    Elapsed: 0:09:05.
#   Batch 3,080  of  3,600.    Elapsed: 0:09:07.
#   Batch 3,090  of  3,600.    Elapsed: 0:09:09.
#   Batch 3,100  of  3,600.    Elapsed: 0:09:11.
#   Batch 3,110  of  3,600.    Elapsed: 0:09:12.
#   Batch 3,120  of  3,600.    Elapsed: 0:09:14.
#   Batch 3,130  of  3,600.    Elapsed: 0:09:16.
#   Batch 3,140  of  3,600.    Elapsed: 0:09:18.
#   Batch 3,150  of  3,600.    Elapsed: 0:09:20.
#   Batch 3,160  of  3,600.    Elapsed: 0:09:21.
#   Batch 3,170  of  3,600.    Elapsed: 0:09:23.
#   Batch 3,180  of  3,600.    Elapsed: 0:09:25.
#   Batch 3,190  of  3,600.    Elapsed: 0:09:27.
#   Batch 3,200  of  3,600.    Elapsed: 0:09:28.
#   Batch 3,210  of  3,600.    Elapsed: 0:09:30.
#   Batch 3,220  of  3,600.    Elapsed: 0:09:32.
#   Batch 3,230  of  3,600.    Elapsed: 0:09:34.
#   Batch 3,240  of  3,600.    Elapsed: 0:09:36.
#   Batch 3,250  of  3,600.    Elapsed: 0:09:37.
#   Batch 3,260  of  3,600.    Elapsed: 0:09:39.
#   Batch 3,270  of  3,600.    Elapsed: 0:09:41.
#   Batch 3,280  of  3,600.    Elapsed: 0:09:43.
#   Batch 3,290  of  3,600.    Elapsed: 0:09:44.
#   Batch 3,300  of  3,600.    Elapsed: 0:09:46.
#   Batch 3,310  of  3,600.    Elapsed: 0:09:48.
#   Batch 3,320  of  3,600.    Elapsed: 0:09:50.
#   Batch 3,330  of  3,600.    Elapsed: 0:09:52.
#   Batch 3,340  of  3,600.    Elapsed: 0:09:53.
#   Batch 3,350  of  3,600.    Elapsed: 0:09:55.
#   Batch 3,360  of  3,600.    Elapsed: 0:09:57.
#   Batch 3,370  of  3,600.    Elapsed: 0:09:59.
#   Batch 3,380  of  3,600.    Elapsed: 0:10:00.
#   Batch 3,390  of  3,600.    Elapsed: 0:10:02.
#   Batch 3,400  of  3,600.    Elapsed: 0:10:04.
#   Batch 3,410  of  3,600.    Elapsed: 0:10:06.
#   Batch 3,420  of  3,600.    Elapsed: 0:10:08.
#   Batch 3,430  of  3,600.    Elapsed: 0:10:09.
#   Batch 3,440  of  3,600.    Elapsed: 0:10:11.
#   Batch 3,450  of  3,600.    Elapsed: 0:10:13.
#   Batch 3,460  of  3,600.    Elapsed: 0:10:15.
#   Batch 3,470  of  3,600.    Elapsed: 0:10:16.
#   Batch 3,480  of  3,600.    Elapsed: 0:10:18.
#   Batch 3,490  of  3,600.    Elapsed: 0:10:20.
#   Batch 3,500  of  3,600.    Elapsed: 0:10:22.
#   Batch 3,510  of  3,600.    Elapsed: 0:10:24.
#   Batch 3,520  of  3,600.    Elapsed: 0:10:25.
#   Batch 3,530  of  3,600.    Elapsed: 0:10:27.
#   Batch 3,540  of  3,600.    Elapsed: 0:10:29.
#   Batch 3,550  of  3,600.    Elapsed: 0:10:31.
#   Batch 3,560  of  3,600.    Elapsed: 0:10:32.
#   Batch 3,570  of  3,600.    Elapsed: 0:10:34.
#   Batch 3,580  of  3,600.    Elapsed: 0:10:36.
#   Batch 3,590  of  3,600.    Elapsed: 0:10:38.
#
#   Average training loss: 0.69
#   Training epcoh took: 0:10:40
#
# Running Validation...
#   Accuracy: 0.55
#   Validation took: 0:00:19
#
# ======== Epoch 2 / 4 ========
# Training...
#   Batch    10  of  3,600.    Elapsed: 0:00:02.
#   Batch    20  of  3,600.    Elapsed: 0:00:04.
#   Batch    30  of  3,600.    Elapsed: 0:00:05.
#   Batch    40  of  3,600.    Elapsed: 0:00:07.
#   Batch    50  of  3,600.    Elapsed: 0:00:09.
#   Batch    60  of  3,600.    Elapsed: 0:00:11.
#   Batch    70  of  3,600.    Elapsed: 0:00:12.
#   Batch    80  of  3,600.    Elapsed: 0:00:14.
#   Batch    90  of  3,600.    Elapsed: 0:00:16.
#   Batch   100  of  3,600.    Elapsed: 0:00:18.
#   Batch   110  of  3,600.    Elapsed: 0:00:20.
#   Batch   120  of  3,600.    Elapsed: 0:00:21.
#   Batch   130  of  3,600.    Elapsed: 0:00:23.
#   Batch   140  of  3,600.    Elapsed: 0:00:25.
#   Batch   150  of  3,600.    Elapsed: 0:00:27.
#   Batch   160  of  3,600.    Elapsed: 0:00:28.
#   Batch   170  of  3,600.    Elapsed: 0:00:30.
#   Batch   180  of  3,600.    Elapsed: 0:00:32.
#   Batch   190  of  3,600.    Elapsed: 0:00:34.
#   Batch   200  of  3,600.    Elapsed: 0:00:36.
#   Batch   210  of  3,600.    Elapsed: 0:00:37.
#   Batch   220  of  3,600.    Elapsed: 0:00:39.
#   Batch   230  of  3,600.    Elapsed: 0:00:41.
#   Batch   240  of  3,600.    Elapsed: 0:00:43.
#   Batch   250  of  3,600.    Elapsed: 0:00:44.
#   Batch   260  of  3,600.    Elapsed: 0:00:46.
#   Batch   270  of  3,600.    Elapsed: 0:00:48.
#   Batch   280  of  3,600.    Elapsed: 0:00:50.
#   Batch   290  of  3,600.    Elapsed: 0:00:52.
#   Batch   300  of  3,600.    Elapsed: 0:00:53.
#   Batch   310  of  3,600.    Elapsed: 0:00:55.
#   Batch   320  of  3,600.    Elapsed: 0:00:57.
#   Batch   330  of  3,600.    Elapsed: 0:00:59.
#   Batch   340  of  3,600.    Elapsed: 0:01:00.
#   Batch   350  of  3,600.    Elapsed: 0:01:02.
#   Batch   360  of  3,600.    Elapsed: 0:01:04.
#   Batch   370  of  3,600.    Elapsed: 0:01:06.
#   Batch   380  of  3,600.    Elapsed: 0:01:08.
#   Batch   390  of  3,600.    Elapsed: 0:01:09.
#   Batch   400  of  3,600.    Elapsed: 0:01:11.
#   Batch   410  of  3,600.    Elapsed: 0:01:13.
#   Batch   420  of  3,600.    Elapsed: 0:01:15.
#   Batch   430  of  3,600.    Elapsed: 0:01:16.
#   Batch   440  of  3,600.    Elapsed: 0:01:18.
#   Batch   450  of  3,600.    Elapsed: 0:01:20.
#   Batch   460  of  3,600.    Elapsed: 0:01:22.
#   Batch   470  of  3,600.    Elapsed: 0:01:24.
#   Batch   480  of  3,600.    Elapsed: 0:01:25.
#   Batch   490  of  3,600.    Elapsed: 0:01:27.
#   Batch   500  of  3,600.    Elapsed: 0:01:29.
#   Batch   510  of  3,600.    Elapsed: 0:01:31.
#   Batch   520  of  3,600.    Elapsed: 0:01:32.
#   Batch   530  of  3,600.    Elapsed: 0:01:34.
#   Batch   540  of  3,600.    Elapsed: 0:01:36.
#   Batch   550  of  3,600.    Elapsed: 0:01:38.
#   Batch   560  of  3,600.    Elapsed: 0:01:40.
#   Batch   570  of  3,600.    Elapsed: 0:01:41.
#   Batch   580  of  3,600.    Elapsed: 0:01:43.
#   Batch   590  of  3,600.    Elapsed: 0:01:45.
#   Batch   600  of  3,600.    Elapsed: 0:01:47.
#   Batch   610  of  3,600.    Elapsed: 0:01:48.
#   Batch   620  of  3,600.    Elapsed: 0:01:50.
#   Batch   630  of  3,600.    Elapsed: 0:01:52.
#   Batch   640  of  3,600.    Elapsed: 0:01:54.
#   Batch   650  of  3,600.    Elapsed: 0:01:56.
#   Batch   660  of  3,600.    Elapsed: 0:01:57.
#   Batch   670  of  3,600.    Elapsed: 0:01:59.
#   Batch   680  of  3,600.    Elapsed: 0:02:01.
#   Batch   690  of  3,600.    Elapsed: 0:02:03.
#   Batch   700  of  3,600.    Elapsed: 0:02:04.
#   Batch   710  of  3,600.    Elapsed: 0:02:06.
#   Batch   720  of  3,600.    Elapsed: 0:02:08.
#   Batch   730  of  3,600.    Elapsed: 0:02:10.
#   Batch   740  of  3,600.    Elapsed: 0:02:12.
#   Batch   750  of  3,600.    Elapsed: 0:02:13.
#   Batch   760  of  3,600.    Elapsed: 0:02:15.
#   Batch   770  of  3,600.    Elapsed: 0:02:17.
#   Batch   780  of  3,600.    Elapsed: 0:02:19.
#   Batch   790  of  3,600.    Elapsed: 0:02:20.
#   Batch   800  of  3,600.    Elapsed: 0:02:22.
#   Batch   810  of  3,600.    Elapsed: 0:02:24.
#   Batch   820  of  3,600.    Elapsed: 0:02:26.
#   Batch   830  of  3,600.    Elapsed: 0:02:28.
#   Batch   840  of  3,600.    Elapsed: 0:02:29.
#   Batch   850  of  3,600.    Elapsed: 0:02:31.
#   Batch   860  of  3,600.    Elapsed: 0:02:33.
#   Batch   870  of  3,600.    Elapsed: 0:02:35.
#   Batch   880  of  3,600.    Elapsed: 0:02:36.
#   Batch   890  of  3,600.    Elapsed: 0:02:38.
#   Batch   900  of  3,600.    Elapsed: 0:02:40.
#   Batch   910  of  3,600.    Elapsed: 0:02:42.
#   Batch   920  of  3,600.    Elapsed: 0:02:44.
#   Batch   930  of  3,600.    Elapsed: 0:02:45.
#   Batch   940  of  3,600.    Elapsed: 0:02:47.
#   Batch   950  of  3,600.    Elapsed: 0:02:49.
#   Batch   960  of  3,600.    Elapsed: 0:02:51.
#   Batch   970  of  3,600.    Elapsed: 0:02:52.
#   Batch   980  of  3,600.    Elapsed: 0:02:54.
#   Batch   990  of  3,600.    Elapsed: 0:02:56.
#   Batch 1,000  of  3,600.    Elapsed: 0:02:58.
#   Batch 1,010  of  3,600.    Elapsed: 0:03:00.
#   Batch 1,020  of  3,600.    Elapsed: 0:03:01.
#   Batch 1,030  of  3,600.    Elapsed: 0:03:03.
#   Batch 1,040  of  3,600.    Elapsed: 0:03:05.
#   Batch 1,050  of  3,600.    Elapsed: 0:03:07.
#   Batch 1,060  of  3,600.    Elapsed: 0:03:08.
#   Batch 1,070  of  3,600.    Elapsed: 0:03:10.
#   Batch 1,080  of  3,600.    Elapsed: 0:03:12.
#   Batch 1,090  of  3,600.    Elapsed: 0:03:14.
#   Batch 1,100  of  3,600.    Elapsed: 0:03:16.
#   Batch 1,110  of  3,600.    Elapsed: 0:03:17.
#   Batch 1,120  of  3,600.    Elapsed: 0:03:19.
#   Batch 1,130  of  3,600.    Elapsed: 0:03:21.
#   Batch 1,140  of  3,600.    Elapsed: 0:03:23.
#   Batch 1,150  of  3,600.    Elapsed: 0:03:24.
#   Batch 1,160  of  3,600.    Elapsed: 0:03:26.
#   Batch 1,170  of  3,600.    Elapsed: 0:03:28.
#   Batch 1,180  of  3,600.    Elapsed: 0:03:30.
#   Batch 1,190  of  3,600.    Elapsed: 0:03:32.
#   Batch 1,200  of  3,600.    Elapsed: 0:03:33.
#   Batch 1,210  of  3,600.    Elapsed: 0:03:35.
#   Batch 1,220  of  3,600.    Elapsed: 0:03:37.
#   Batch 1,230  of  3,600.    Elapsed: 0:03:39.
#   Batch 1,240  of  3,600.    Elapsed: 0:03:40.
#   Batch 1,250  of  3,600.    Elapsed: 0:03:42.
#   Batch 1,260  of  3,600.    Elapsed: 0:03:44.
#   Batch 1,270  of  3,600.    Elapsed: 0:03:46.
#   Batch 1,280  of  3,600.    Elapsed: 0:03:48.
#   Batch 1,290  of  3,600.    Elapsed: 0:03:49.
#   Batch 1,300  of  3,600.    Elapsed: 0:03:51.
#   Batch 1,310  of  3,600.    Elapsed: 0:03:53.
#   Batch 1,320  of  3,600.    Elapsed: 0:03:55.
#   Batch 1,330  of  3,600.    Elapsed: 0:03:56.
#   Batch 1,340  of  3,600.    Elapsed: 0:03:58.
#   Batch 1,350  of  3,600.    Elapsed: 0:04:00.
#   Batch 1,360  of  3,600.    Elapsed: 0:04:02.
#   Batch 1,370  of  3,600.    Elapsed: 0:04:04.
#   Batch 1,380  of  3,600.    Elapsed: 0:04:05.
#   Batch 1,390  of  3,600.    Elapsed: 0:04:07.
#   Batch 1,400  of  3,600.    Elapsed: 0:04:09.
#   Batch 1,410  of  3,600.    Elapsed: 0:04:11.
#   Batch 1,420  of  3,600.    Elapsed: 0:04:12.
#   Batch 1,430  of  3,600.    Elapsed: 0:04:14.
#   Batch 1,440  of  3,600.    Elapsed: 0:04:16.
#   Batch 1,450  of  3,600.    Elapsed: 0:04:18.
#   Batch 1,460  of  3,600.    Elapsed: 0:04:20.
#   Batch 1,470  of  3,600.    Elapsed: 0:04:21.
#   Batch 1,480  of  3,600.    Elapsed: 0:04:23.
#   Batch 1,490  of  3,600.    Elapsed: 0:04:25.
#   Batch 1,500  of  3,600.    Elapsed: 0:04:27.
#   Batch 1,510  of  3,600.    Elapsed: 0:04:28.
#   Batch 1,520  of  3,600.    Elapsed: 0:04:30.
#   Batch 1,530  of  3,600.    Elapsed: 0:04:32.
#   Batch 1,540  of  3,600.    Elapsed: 0:04:34.
#   Batch 1,550  of  3,600.    Elapsed: 0:04:36.
#   Batch 1,560  of  3,600.    Elapsed: 0:04:37.
#   Batch 1,570  of  3,600.    Elapsed: 0:04:39.
#   Batch 1,580  of  3,600.    Elapsed: 0:04:41.
#   Batch 1,590  of  3,600.    Elapsed: 0:04:43.
#   Batch 1,600  of  3,600.    Elapsed: 0:04:44.
#   Batch 1,610  of  3,600.    Elapsed: 0:04:46.
#   Batch 1,620  of  3,600.    Elapsed: 0:04:48.
#   Batch 1,630  of  3,600.    Elapsed: 0:04:50.
#   Batch 1,640  of  3,600.    Elapsed: 0:04:52.
#   Batch 1,650  of  3,600.    Elapsed: 0:04:53.
#   Batch 1,660  of  3,600.    Elapsed: 0:04:55.
#   Batch 1,670  of  3,600.    Elapsed: 0:04:57.
#   Batch 1,680  of  3,600.    Elapsed: 0:04:59.
#   Batch 1,690  of  3,600.    Elapsed: 0:05:00.
#   Batch 1,700  of  3,600.    Elapsed: 0:05:02.
#   Batch 1,710  of  3,600.    Elapsed: 0:05:04.
#   Batch 1,720  of  3,600.    Elapsed: 0:05:06.
#   Batch 1,730  of  3,600.    Elapsed: 0:05:08.
#   Batch 1,740  of  3,600.    Elapsed: 0:05:09.
#   Batch 1,750  of  3,600.    Elapsed: 0:05:11.
#   Batch 1,760  of  3,600.    Elapsed: 0:05:13.
#   Batch 1,770  of  3,600.    Elapsed: 0:05:15.
#   Batch 1,780  of  3,600.    Elapsed: 0:05:16.
#   Batch 1,790  of  3,600.    Elapsed: 0:05:18.
#   Batch 1,800  of  3,600.    Elapsed: 0:05:20.
#   Batch 1,810  of  3,600.    Elapsed: 0:05:22.
#   Batch 1,820  of  3,600.    Elapsed: 0:05:24.
#   Batch 1,830  of  3,600.    Elapsed: 0:05:25.
#   Batch 1,840  of  3,600.    Elapsed: 0:05:27.
#   Batch 1,850  of  3,600.    Elapsed: 0:05:29.
#   Batch 1,860  of  3,600.    Elapsed: 0:05:31.
#   Batch 1,870  of  3,600.    Elapsed: 0:05:33.
#   Batch 1,880  of  3,600.    Elapsed: 0:05:34.
#   Batch 1,890  of  3,600.    Elapsed: 0:05:36.
#   Batch 1,900  of  3,600.    Elapsed: 0:05:38.
#   Batch 1,910  of  3,600.    Elapsed: 0:05:40.
#   Batch 1,920  of  3,600.    Elapsed: 0:05:41.
#   Batch 1,930  of  3,600.    Elapsed: 0:05:43.
#   Batch 1,940  of  3,600.    Elapsed: 0:05:45.
#   Batch 1,950  of  3,600.    Elapsed: 0:05:47.
#   Batch 1,960  of  3,600.    Elapsed: 0:05:49.
#   Batch 1,970  of  3,600.    Elapsed: 0:05:50.
#   Batch 1,980  of  3,600.    Elapsed: 0:05:52.
#   Batch 1,990  of  3,600.    Elapsed: 0:05:54.
#   Batch 2,000  of  3,600.    Elapsed: 0:05:56.
#   Batch 2,010  of  3,600.    Elapsed: 0:05:57.
#   Batch 2,020  of  3,600.    Elapsed: 0:05:59.
#   Batch 2,030  of  3,600.    Elapsed: 0:06:01.
#   Batch 2,040  of  3,600.    Elapsed: 0:06:03.
#   Batch 2,050  of  3,600.    Elapsed: 0:06:05.
#   Batch 2,060  of  3,600.    Elapsed: 0:06:06.
#   Batch 2,070  of  3,600.    Elapsed: 0:06:08.
#   Batch 2,080  of  3,600.    Elapsed: 0:06:10.
#   Batch 2,090  of  3,600.    Elapsed: 0:06:12.
#   Batch 2,100  of  3,600.    Elapsed: 0:06:13.
#   Batch 2,110  of  3,600.    Elapsed: 0:06:15.
#   Batch 2,120  of  3,600.    Elapsed: 0:06:17.
#   Batch 2,130  of  3,600.    Elapsed: 0:06:19.
#   Batch 2,140  of  3,600.    Elapsed: 0:06:21.
#   Batch 2,150  of  3,600.    Elapsed: 0:06:22.
#   Batch 2,160  of  3,600.    Elapsed: 0:06:24.
#   Batch 2,170  of  3,600.    Elapsed: 0:06:26.
#   Batch 2,180  of  3,600.    Elapsed: 0:06:28.
#   Batch 2,190  of  3,600.    Elapsed: 0:06:29.
#   Batch 2,200  of  3,600.    Elapsed: 0:06:31.
#   Batch 2,210  of  3,600.    Elapsed: 0:06:33.
#   Batch 2,220  of  3,600.    Elapsed: 0:06:35.
#   Batch 2,230  of  3,600.    Elapsed: 0:06:37.
#   Batch 2,240  of  3,600.    Elapsed: 0:06:38.
#   Batch 2,250  of  3,600.    Elapsed: 0:06:40.
#   Batch 2,260  of  3,600.    Elapsed: 0:06:42.
#   Batch 2,270  of  3,600.    Elapsed: 0:06:44.
#   Batch 2,280  of  3,600.    Elapsed: 0:06:45.
#   Batch 2,290  of  3,600.    Elapsed: 0:06:47.
#   Batch 2,300  of  3,600.    Elapsed: 0:06:49.
#   Batch 2,310  of  3,600.    Elapsed: 0:06:51.
#   Batch 2,320  of  3,600.    Elapsed: 0:06:53.
#   Batch 2,330  of  3,600.    Elapsed: 0:06:54.
#   Batch 2,340  of  3,600.    Elapsed: 0:06:56.
#   Batch 2,350  of  3,600.    Elapsed: 0:06:58.
#   Batch 2,360  of  3,600.    Elapsed: 0:07:00.
#   Batch 2,370  of  3,600.    Elapsed: 0:07:01.
#   Batch 2,380  of  3,600.    Elapsed: 0:07:03.
#   Batch 2,390  of  3,600.    Elapsed: 0:07:05.
#   Batch 2,400  of  3,600.    Elapsed: 0:07:07.
#   Batch 2,410  of  3,600.    Elapsed: 0:07:09.
#   Batch 2,420  of  3,600.    Elapsed: 0:07:10.
#   Batch 2,430  of  3,600.    Elapsed: 0:07:12.
#   Batch 2,440  of  3,600.    Elapsed: 0:07:14.
#   Batch 2,450  of  3,600.    Elapsed: 0:07:16.
#   Batch 2,460  of  3,600.    Elapsed: 0:07:18.
#   Batch 2,470  of  3,600.    Elapsed: 0:07:19.
#   Batch 2,480  of  3,600.    Elapsed: 0:07:21.
#   Batch 2,490  of  3,600.    Elapsed: 0:07:23.
#   Batch 2,500  of  3,600.    Elapsed: 0:07:25.
#   Batch 2,510  of  3,600.    Elapsed: 0:07:26.
#   Batch 2,520  of  3,600.    Elapsed: 0:07:28.
#   Batch 2,530  of  3,600.    Elapsed: 0:07:30.
#   Batch 2,540  of  3,600.    Elapsed: 0:07:32.
#   Batch 2,550  of  3,600.    Elapsed: 0:07:34.
#   Batch 2,560  of  3,600.    Elapsed: 0:07:35.
#   Batch 2,570  of  3,600.    Elapsed: 0:07:37.
#   Batch 2,580  of  3,600.    Elapsed: 0:07:39.
#   Batch 2,590  of  3,600.    Elapsed: 0:07:41.
#   Batch 2,600  of  3,600.    Elapsed: 0:07:42.
#   Batch 2,610  of  3,600.    Elapsed: 0:07:44.
#   Batch 2,620  of  3,600.    Elapsed: 0:07:46.
#   Batch 2,630  of  3,600.    Elapsed: 0:07:48.
#   Batch 2,640  of  3,600.    Elapsed: 0:07:50.
#   Batch 2,650  of  3,600.    Elapsed: 0:07:51.
#   Batch 2,660  of  3,600.    Elapsed: 0:07:53.
#   Batch 2,670  of  3,600.    Elapsed: 0:07:55.
#   Batch 2,680  of  3,600.    Elapsed: 0:07:57.
#   Batch 2,690  of  3,600.    Elapsed: 0:07:58.
#   Batch 2,700  of  3,600.    Elapsed: 0:08:00.
#   Batch 2,710  of  3,600.    Elapsed: 0:08:02.
#   Batch 2,720  of  3,600.    Elapsed: 0:08:04.
#   Batch 2,730  of  3,600.    Elapsed: 0:08:06.
#   Batch 2,740  of  3,600.    Elapsed: 0:08:07.
#   Batch 2,750  of  3,600.    Elapsed: 0:08:09.
#   Batch 2,760  of  3,600.    Elapsed: 0:08:11.
#   Batch 2,770  of  3,600.    Elapsed: 0:08:13.
#   Batch 2,780  of  3,600.    Elapsed: 0:08:15.
#   Batch 2,790  of  3,600.    Elapsed: 0:08:16.
#   Batch 2,800  of  3,600.    Elapsed: 0:08:18.
#   Batch 2,810  of  3,600.    Elapsed: 0:08:20.
#   Batch 2,820  of  3,600.    Elapsed: 0:08:22.
#   Batch 2,830  of  3,600.    Elapsed: 0:08:23.
#   Batch 2,840  of  3,600.    Elapsed: 0:08:25.
#   Batch 2,850  of  3,600.    Elapsed: 0:08:27.
#   Batch 2,860  of  3,600.    Elapsed: 0:08:29.
#   Batch 2,870  of  3,600.    Elapsed: 0:08:31.
#   Batch 2,880  of  3,600.    Elapsed: 0:08:32.
#   Batch 2,890  of  3,600.    Elapsed: 0:08:34.
#   Batch 2,900  of  3,600.    Elapsed: 0:08:36.
#   Batch 2,910  of  3,600.    Elapsed: 0:08:38.
#   Batch 2,920  of  3,600.    Elapsed: 0:08:39.
#   Batch 2,930  of  3,600.    Elapsed: 0:08:41.
#   Batch 2,940  of  3,600.    Elapsed: 0:08:43.
#   Batch 2,950  of  3,600.    Elapsed: 0:08:45.
#   Batch 2,960  of  3,600.    Elapsed: 0:08:47.
#   Batch 2,970  of  3,600.    Elapsed: 0:08:48.
#   Batch 2,980  of  3,600.    Elapsed: 0:08:50.
#   Batch 2,990  of  3,600.    Elapsed: 0:08:52.
#   Batch 3,000  of  3,600.    Elapsed: 0:08:54.
#   Batch 3,010  of  3,600.    Elapsed: 0:08:55.
#   Batch 3,020  of  3,600.    Elapsed: 0:08:57.
#   Batch 3,030  of  3,600.    Elapsed: 0:08:59.
#   Batch 3,040  of  3,600.    Elapsed: 0:09:01.
#   Batch 3,050  of  3,600.    Elapsed: 0:09:03.
#   Batch 3,060  of  3,600.    Elapsed: 0:09:04.
#   Batch 3,070  of  3,600.    Elapsed: 0:09:06.
#   Batch 3,080  of  3,600.    Elapsed: 0:09:08.
#   Batch 3,090  of  3,600.    Elapsed: 0:09:10.
#   Batch 3,100  of  3,600.    Elapsed: 0:09:11.
#   Batch 3,110  of  3,600.    Elapsed: 0:09:13.
#   Batch 3,120  of  3,600.    Elapsed: 0:09:15.
#   Batch 3,130  of  3,600.    Elapsed: 0:09:17.
#   Batch 3,140  of  3,600.    Elapsed: 0:09:19.
#   Batch 3,150  of  3,600.    Elapsed: 0:09:20.
#   Batch 3,160  of  3,600.    Elapsed: 0:09:22.
#   Batch 3,170  of  3,600.    Elapsed: 0:09:24.
#   Batch 3,180  of  3,600.    Elapsed: 0:09:26.
#   Batch 3,190  of  3,600.    Elapsed: 0:09:27.
#   Batch 3,200  of  3,600.    Elapsed: 0:09:29.
#   Batch 3,210  of  3,600.    Elapsed: 0:09:31.
#   Batch 3,220  of  3,600.    Elapsed: 0:09:33.
#   Batch 3,230  of  3,600.    Elapsed: 0:09:35.
#   Batch 3,240  of  3,600.    Elapsed: 0:09:36.
#   Batch 3,250  of  3,600.    Elapsed: 0:09:38.
#   Batch 3,260  of  3,600.    Elapsed: 0:09:40.
#   Batch 3,270  of  3,600.    Elapsed: 0:09:42.
#   Batch 3,280  of  3,600.    Elapsed: 0:09:43.
#   Batch 3,290  of  3,600.    Elapsed: 0:09:45.
#   Batch 3,300  of  3,600.    Elapsed: 0:09:47.
#   Batch 3,310  of  3,600.    Elapsed: 0:09:49.
#   Batch 3,320  of  3,600.    Elapsed: 0:09:51.
#   Batch 3,330  of  3,600.    Elapsed: 0:09:52.
#   Batch 3,340  of  3,600.    Elapsed: 0:09:54.
#   Batch 3,350  of  3,600.    Elapsed: 0:09:56.
#   Batch 3,360  of  3,600.    Elapsed: 0:09:58.
#   Batch 3,370  of  3,600.    Elapsed: 0:10:00.
#   Batch 3,380  of  3,600.    Elapsed: 0:10:01.
#   Batch 3,390  of  3,600.    Elapsed: 0:10:03.
#   Batch 3,400  of  3,600.    Elapsed: 0:10:05.
#   Batch 3,410  of  3,600.    Elapsed: 0:10:07.
#   Batch 3,420  of  3,600.    Elapsed: 0:10:08.
#   Batch 3,430  of  3,600.    Elapsed: 0:10:10.
#   Batch 3,440  of  3,600.    Elapsed: 0:10:12.
#   Batch 3,450  of  3,600.    Elapsed: 0:10:14.
#   Batch 3,460  of  3,600.    Elapsed: 0:10:16.
#   Batch 3,470  of  3,600.    Elapsed: 0:10:17.
#   Batch 3,480  of  3,600.    Elapsed: 0:10:19.
#   Batch 3,490  of  3,600.    Elapsed: 0:10:21.
#   Batch 3,500  of  3,600.    Elapsed: 0:10:23.
#   Batch 3,510  of  3,600.    Elapsed: 0:10:24.
#   Batch 3,520  of  3,600.    Elapsed: 0:10:26.
#   Batch 3,530  of  3,600.    Elapsed: 0:10:28.
#   Batch 3,540  of  3,600.    Elapsed: 0:10:30.
#   Batch 3,550  of  3,600.    Elapsed: 0:10:32.
#   Batch 3,560  of  3,600.    Elapsed: 0:10:33.
#   Batch 3,570  of  3,600.    Elapsed: 0:10:35.
#   Batch 3,580  of  3,600.    Elapsed: 0:10:37.
#   Batch 3,590  of  3,600.    Elapsed: 0:10:39.
#
#   Average training loss: 0.67
#   Training epcoh took: 0:10:40
#
# Running Validation...
#   Accuracy: 0.57
#   Validation took: 0:00:19
#
# ======== Epoch 3 / 4 ========
# Training...
#   Batch    10  of  3,600.    Elapsed: 0:00:02.
#   Batch    20  of  3,600.    Elapsed: 0:00:04.
#   Batch    30  of  3,600.    Elapsed: 0:00:05.
#   Batch    40  of  3,600.    Elapsed: 0:00:07.
#   Batch    50  of  3,600.    Elapsed: 0:00:09.
#   Batch    60  of  3,600.    Elapsed: 0:00:11.
#   Batch    70  of  3,600.    Elapsed: 0:00:12.
#   Batch    80  of  3,600.    Elapsed: 0:00:14.
#   Batch    90  of  3,600.    Elapsed: 0:00:16.
#   Batch   100  of  3,600.    Elapsed: 0:00:18.
#   Batch   110  of  3,600.    Elapsed: 0:00:20.
#   Batch   120  of  3,600.    Elapsed: 0:00:21.
#   Batch   130  of  3,600.    Elapsed: 0:00:23.
#   Batch   140  of  3,600.    Elapsed: 0:00:25.
#   Batch   150  of  3,600.    Elapsed: 0:00:27.
#   Batch   160  of  3,600.    Elapsed: 0:00:28.
#   Batch   170  of  3,600.    Elapsed: 0:00:30.
#   Batch   180  of  3,600.    Elapsed: 0:00:32.
#   Batch   190  of  3,600.    Elapsed: 0:00:34.
#   Batch   200  of  3,600.    Elapsed: 0:00:36.
#   Batch   210  of  3,600.    Elapsed: 0:00:37.
#   Batch   220  of  3,600.    Elapsed: 0:00:39.
#   Batch   230  of  3,600.    Elapsed: 0:00:41.
#   Batch   240  of  3,600.    Elapsed: 0:00:43.
#   Batch   250  of  3,600.    Elapsed: 0:00:44.
#   Batch   260  of  3,600.    Elapsed: 0:00:46.
#   Batch   270  of  3,600.    Elapsed: 0:00:48.
#   Batch   280  of  3,600.    Elapsed: 0:00:50.
#   Batch   290  of  3,600.    Elapsed: 0:00:52.
#   Batch   300  of  3,600.    Elapsed: 0:00:53.
#   Batch   310  of  3,600.    Elapsed: 0:00:55.
#   Batch   320  of  3,600.    Elapsed: 0:00:57.
#   Batch   330  of  3,600.    Elapsed: 0:00:59.
#   Batch   340  of  3,600.    Elapsed: 0:01:00.
#   Batch   350  of  3,600.    Elapsed: 0:01:02.
#   Batch   360  of  3,600.    Elapsed: 0:01:04.
#   Batch   370  of  3,600.    Elapsed: 0:01:06.
#   Batch   380  of  3,600.    Elapsed: 0:01:08.
#   Batch   390  of  3,600.    Elapsed: 0:01:09.
#   Batch   400  of  3,600.    Elapsed: 0:01:11.
#   Batch   410  of  3,600.    Elapsed: 0:01:13.
#   Batch   420  of  3,600.    Elapsed: 0:01:15.
#   Batch   430  of  3,600.    Elapsed: 0:01:16.
#   Batch   440  of  3,600.    Elapsed: 0:01:18.
#   Batch   450  of  3,600.    Elapsed: 0:01:20.
#   Batch   460  of  3,600.    Elapsed: 0:01:22.
#   Batch   470  of  3,600.    Elapsed: 0:01:24.
#   Batch   480  of  3,600.    Elapsed: 0:01:25.
#   Batch   490  of  3,600.    Elapsed: 0:01:27.
#   Batch   500  of  3,600.    Elapsed: 0:01:29.
#   Batch   510  of  3,600.    Elapsed: 0:01:31.
#   Batch   520  of  3,600.    Elapsed: 0:01:32.
#   Batch   530  of  3,600.    Elapsed: 0:01:34.
#   Batch   540  of  3,600.    Elapsed: 0:01:36.
#   Batch   550  of  3,600.    Elapsed: 0:01:38.
#   Batch   560  of  3,600.    Elapsed: 0:01:40.
#   Batch   570  of  3,600.    Elapsed: 0:01:41.
#   Batch   580  of  3,600.    Elapsed: 0:01:43.
#   Batch   590  of  3,600.    Elapsed: 0:01:45.
#   Batch   600  of  3,600.    Elapsed: 0:01:47.
#   Batch   610  of  3,600.    Elapsed: 0:01:48.
#   Batch   620  of  3,600.    Elapsed: 0:01:50.
#   Batch   630  of  3,600.    Elapsed: 0:01:52.
#   Batch   640  of  3,600.    Elapsed: 0:01:54.
#   Batch   650  of  3,600.    Elapsed: 0:01:56.
#   Batch   660  of  3,600.    Elapsed: 0:01:57.
#   Batch   670  of  3,600.    Elapsed: 0:01:59.
#   Batch   680  of  3,600.    Elapsed: 0:02:01.
#   Batch   690  of  3,600.    Elapsed: 0:02:03.
#   Batch   700  of  3,600.    Elapsed: 0:02:05.
#   Batch   710  of  3,600.    Elapsed: 0:02:06.
#   Batch   720  of  3,600.    Elapsed: 0:02:08.
#   Batch   730  of  3,600.    Elapsed: 0:02:10.
#   Batch   740  of  3,600.    Elapsed: 0:02:12.
#   Batch   750  of  3,600.    Elapsed: 0:02:13.
#   Batch   760  of  3,600.    Elapsed: 0:02:15.
#   Batch   770  of  3,600.    Elapsed: 0:02:17.
#   Batch   780  of  3,600.    Elapsed: 0:02:19.
#   Batch   790  of  3,600.    Elapsed: 0:02:21.
#   Batch   800  of  3,600.    Elapsed: 0:02:22.
#   Batch   810  of  3,600.    Elapsed: 0:02:24.
#   Batch   820  of  3,600.    Elapsed: 0:02:26.
#   Batch   830  of  3,600.    Elapsed: 0:02:28.
#   Batch   840  of  3,600.    Elapsed: 0:02:29.
#   Batch   850  of  3,600.    Elapsed: 0:02:31.
#   Batch   860  of  3,600.    Elapsed: 0:02:33.
#   Batch   870  of  3,600.    Elapsed: 0:02:35.
#   Batch   880  of  3,600.    Elapsed: 0:02:37.
#   Batch   890  of  3,600.    Elapsed: 0:02:38.
#   Batch   900  of  3,600.    Elapsed: 0:02:40.
#   Batch   910  of  3,600.    Elapsed: 0:02:42.
#   Batch   920  of  3,600.    Elapsed: 0:02:44.
#   Batch   930  of  3,600.    Elapsed: 0:02:45.
#   Batch   940  of  3,600.    Elapsed: 0:02:47.
#   Batch   950  of  3,600.    Elapsed: 0:02:49.
#   Batch   960  of  3,600.    Elapsed: 0:02:51.
#   Batch   970  of  3,600.    Elapsed: 0:02:53.
#   Batch   980  of  3,600.    Elapsed: 0:02:54.
#   Batch   990  of  3,600.    Elapsed: 0:02:56.
#   Batch 1,000  of  3,600.    Elapsed: 0:02:58.
#   Batch 1,010  of  3,600.    Elapsed: 0:03:00.
#   Batch 1,020  of  3,600.    Elapsed: 0:03:01.
#   Batch 1,030  of  3,600.    Elapsed: 0:03:03.
#   Batch 1,040  of  3,600.    Elapsed: 0:03:05.
#   Batch 1,050  of  3,600.    Elapsed: 0:03:07.
#   Batch 1,060  of  3,600.    Elapsed: 0:03:09.
#   Batch 1,070  of  3,600.    Elapsed: 0:03:10.
#   Batch 1,080  of  3,600.    Elapsed: 0:03:12.
#   Batch 1,090  of  3,600.    Elapsed: 0:03:14.
#   Batch 1,100  of  3,600.    Elapsed: 0:03:16.
#   Batch 1,110  of  3,600.    Elapsed: 0:03:17.
#   Batch 1,120  of  3,600.    Elapsed: 0:03:19.
#   Batch 1,130  of  3,600.    Elapsed: 0:03:21.
#   Batch 1,140  of  3,600.    Elapsed: 0:03:23.
#   Batch 1,150  of  3,600.    Elapsed: 0:03:25.
#   Batch 1,160  of  3,600.    Elapsed: 0:03:26.
#   Batch 1,170  of  3,600.    Elapsed: 0:03:28.
#   Batch 1,180  of  3,600.    Elapsed: 0:03:30.
#   Batch 1,190  of  3,600.    Elapsed: 0:03:32.
#   Batch 1,200  of  3,600.    Elapsed: 0:03:33.
#   Batch 1,210  of  3,600.    Elapsed: 0:03:35.
#   Batch 1,220  of  3,600.    Elapsed: 0:03:37.
#   Batch 1,230  of  3,600.    Elapsed: 0:03:39.
#   Batch 1,240  of  3,600.    Elapsed: 0:03:41.
#   Batch 1,250  of  3,600.    Elapsed: 0:03:42.
#   Batch 1,260  of  3,600.    Elapsed: 0:03:44.
#   Batch 1,270  of  3,600.    Elapsed: 0:03:46.
#   Batch 1,280  of  3,600.    Elapsed: 0:03:48.
#   Batch 1,290  of  3,600.    Elapsed: 0:03:49.
#   Batch 1,300  of  3,600.    Elapsed: 0:03:51.
#   Batch 1,310  of  3,600.    Elapsed: 0:03:53.
#   Batch 1,320  of  3,600.    Elapsed: 0:03:55.
#   Batch 1,330  of  3,600.    Elapsed: 0:03:57.
#   Batch 1,340  of  3,600.    Elapsed: 0:03:58.
#   Batch 1,350  of  3,600.    Elapsed: 0:04:00.
#   Batch 1,360  of  3,600.    Elapsed: 0:04:02.
#   Batch 1,370  of  3,600.    Elapsed: 0:04:04.
#   Batch 1,380  of  3,600.    Elapsed: 0:04:05.
#   Batch 1,390  of  3,600.    Elapsed: 0:04:07.
#   Batch 1,400  of  3,600.    Elapsed: 0:04:09.
#   Batch 1,410  of  3,600.    Elapsed: 0:04:11.
#   Batch 1,420  of  3,600.    Elapsed: 0:04:13.
#   Batch 1,430  of  3,600.    Elapsed: 0:04:14.
#   Batch 1,440  of  3,600.    Elapsed: 0:04:16.
#   Batch 1,450  of  3,600.    Elapsed: 0:04:18.
#   Batch 1,460  of  3,600.    Elapsed: 0:04:20.
#   Batch 1,470  of  3,600.    Elapsed: 0:04:21.
#   Batch 1,480  of  3,600.    Elapsed: 0:04:23.
#   Batch 1,490  of  3,600.    Elapsed: 0:04:25.
#   Batch 1,500  of  3,600.    Elapsed: 0:04:27.
#   Batch 1,510  of  3,600.    Elapsed: 0:04:29.
#   Batch 1,520  of  3,600.    Elapsed: 0:04:30.
#   Batch 1,530  of  3,600.    Elapsed: 0:04:32.
#   Batch 1,540  of  3,600.    Elapsed: 0:04:34.
#   Batch 1,550  of  3,600.    Elapsed: 0:04:36.
#   Batch 1,560  of  3,600.    Elapsed: 0:04:37.
#   Batch 1,570  of  3,600.    Elapsed: 0:04:39.
#   Batch 1,580  of  3,600.    Elapsed: 0:04:41.
#   Batch 1,590  of  3,600.    Elapsed: 0:04:43.
#   Batch 1,600  of  3,600.    Elapsed: 0:04:45.
#   Batch 1,610  of  3,600.    Elapsed: 0:04:46.
#   Batch 1,620  of  3,600.    Elapsed: 0:04:48.
#   Batch 1,630  of  3,600.    Elapsed: 0:04:50.
#   Batch 1,640  of  3,600.    Elapsed: 0:04:52.
#   Batch 1,650  of  3,600.    Elapsed: 0:04:53.
#   Batch 1,660  of  3,600.    Elapsed: 0:04:55.
#   Batch 1,670  of  3,600.    Elapsed: 0:04:57.
#   Batch 1,680  of  3,600.    Elapsed: 0:04:59.
#   Batch 1,690  of  3,600.    Elapsed: 0:05:01.
#   Batch 1,700  of  3,600.    Elapsed: 0:05:02.
#   Batch 1,710  of  3,600.    Elapsed: 0:05:04.
#   Batch 1,720  of  3,600.    Elapsed: 0:05:06.
#   Batch 1,730  of  3,600.    Elapsed: 0:05:08.
#   Batch 1,740  of  3,600.    Elapsed: 0:05:09.
#   Batch 1,750  of  3,600.    Elapsed: 0:05:11.
#   Batch 1,760  of  3,600.    Elapsed: 0:05:13.
#   Batch 1,770  of  3,600.    Elapsed: 0:05:15.
#   Batch 1,780  of  3,600.    Elapsed: 0:05:17.
#   Batch 1,790  of  3,600.    Elapsed: 0:05:18.
#   Batch 1,800  of  3,600.    Elapsed: 0:05:20.
#   Batch 1,810  of  3,600.    Elapsed: 0:05:22.
#   Batch 1,820  of  3,600.    Elapsed: 0:05:24.
#   Batch 1,830  of  3,600.    Elapsed: 0:05:25.
#   Batch 1,840  of  3,600.    Elapsed: 0:05:27.
#   Batch 1,850  of  3,600.    Elapsed: 0:05:29.
#   Batch 1,860  of  3,600.    Elapsed: 0:05:31.
#   Batch 1,870  of  3,600.    Elapsed: 0:05:33.
#   Batch 1,880  of  3,600.    Elapsed: 0:05:34.
#   Batch 1,890  of  3,600.    Elapsed: 0:05:36.
#   Batch 1,900  of  3,600.    Elapsed: 0:05:38.
#   Batch 1,910  of  3,600.    Elapsed: 0:05:40.
#   Batch 1,920  of  3,600.    Elapsed: 0:05:41.
#   Batch 1,930  of  3,600.    Elapsed: 0:05:43.
#   Batch 1,940  of  3,600.    Elapsed: 0:05:45.
#   Batch 1,950  of  3,600.    Elapsed: 0:05:47.
#   Batch 1,960  of  3,600.    Elapsed: 0:05:49.
#   Batch 1,970  of  3,600.    Elapsed: 0:05:50.
#   Batch 1,980  of  3,600.    Elapsed: 0:05:52.
#   Batch 1,990  of  3,600.    Elapsed: 0:05:54.
#   Batch 2,000  of  3,600.    Elapsed: 0:05:56.
#   Batch 2,010  of  3,600.    Elapsed: 0:05:57.
#   Batch 2,020  of  3,600.    Elapsed: 0:05:59.
#   Batch 2,030  of  3,600.    Elapsed: 0:06:01.
#   Batch 2,040  of  3,600.    Elapsed: 0:06:03.
#   Batch 2,050  of  3,600.    Elapsed: 0:06:05.
#   Batch 2,060  of  3,600.    Elapsed: 0:06:06.
#   Batch 2,070  of  3,600.    Elapsed: 0:06:08.
#   Batch 2,080  of  3,600.    Elapsed: 0:06:10.
#   Batch 2,090  of  3,600.    Elapsed: 0:06:12.
#   Batch 2,100  of  3,600.    Elapsed: 0:06:13.
#   Batch 2,110  of  3,600.    Elapsed: 0:06:15.
#   Batch 2,120  of  3,600.    Elapsed: 0:06:17.
#   Batch 2,130  of  3,600.    Elapsed: 0:06:19.
#   Batch 2,140  of  3,600.    Elapsed: 0:06:21.
#   Batch 2,150  of  3,600.    Elapsed: 0:06:22.
#   Batch 2,160  of  3,600.    Elapsed: 0:06:24.
#   Batch 2,170  of  3,600.    Elapsed: 0:06:26.
#   Batch 2,180  of  3,600.    Elapsed: 0:06:28.
#   Batch 2,190  of  3,600.    Elapsed: 0:06:29.
#   Batch 2,200  of  3,600.    Elapsed: 0:06:31.
#   Batch 2,210  of  3,600.    Elapsed: 0:06:33.
#   Batch 2,220  of  3,600.    Elapsed: 0:06:35.
#   Batch 2,230  of  3,600.    Elapsed: 0:06:37.
#   Batch 2,240  of  3,600.    Elapsed: 0:06:38.
#   Batch 2,250  of  3,600.    Elapsed: 0:06:40.
#   Batch 2,260  of  3,600.    Elapsed: 0:06:42.
#   Batch 2,270  of  3,600.    Elapsed: 0:06:44.
#   Batch 2,280  of  3,600.    Elapsed: 0:06:45.
#   Batch 2,290  of  3,600.    Elapsed: 0:06:47.
#   Batch 2,300  of  3,600.    Elapsed: 0:06:49.
#   Batch 2,310  of  3,600.    Elapsed: 0:06:51.
#   Batch 2,320  of  3,600.    Elapsed: 0:06:53.
#   Batch 2,330  of  3,600.    Elapsed: 0:06:54.
#   Batch 2,340  of  3,600.    Elapsed: 0:06:56.
#   Batch 2,350  of  3,600.    Elapsed: 0:06:58.
#   Batch 2,360  of  3,600.    Elapsed: 0:07:00.
#   Batch 2,370  of  3,600.    Elapsed: 0:07:01.
#   Batch 2,380  of  3,600.    Elapsed: 0:07:03.
#   Batch 2,390  of  3,600.    Elapsed: 0:07:05.
#   Batch 2,400  of  3,600.    Elapsed: 0:07:07.
#   Batch 2,410  of  3,600.    Elapsed: 0:07:09.
#   Batch 2,420  of  3,600.    Elapsed: 0:07:10.
#   Batch 2,430  of  3,600.    Elapsed: 0:07:12.
#   Batch 2,440  of  3,600.    Elapsed: 0:07:14.
#   Batch 2,450  of  3,600.    Elapsed: 0:07:16.
#   Batch 2,460  of  3,600.    Elapsed: 0:07:17.
#   Batch 2,470  of  3,600.    Elapsed: 0:07:19.
#   Batch 2,480  of  3,600.    Elapsed: 0:07:21.
#   Batch 2,490  of  3,600.    Elapsed: 0:07:23.
#   Batch 2,500  of  3,600.    Elapsed: 0:07:25.
#   Batch 2,510  of  3,600.    Elapsed: 0:07:26.
#   Batch 2,520  of  3,600.    Elapsed: 0:07:28.
#   Batch 2,530  of  3,600.    Elapsed: 0:07:30.
#   Batch 2,540  of  3,600.    Elapsed: 0:07:32.
#   Batch 2,550  of  3,600.    Elapsed: 0:07:33.
#   Batch 2,560  of  3,600.    Elapsed: 0:07:35.
#   Batch 2,570  of  3,600.    Elapsed: 0:07:37.
#   Batch 2,580  of  3,600.    Elapsed: 0:07:39.
#   Batch 2,590  of  3,600.    Elapsed: 0:07:41.
#   Batch 2,600  of  3,600.    Elapsed: 0:07:42.
#   Batch 2,610  of  3,600.    Elapsed: 0:07:44.
#   Batch 2,620  of  3,600.    Elapsed: 0:07:46.
#   Batch 2,630  of  3,600.    Elapsed: 0:07:48.
#   Batch 2,640  of  3,600.    Elapsed: 0:07:49.
#   Batch 2,650  of  3,600.    Elapsed: 0:07:51.
#   Batch 2,660  of  3,600.    Elapsed: 0:07:53.
#   Batch 2,670  of  3,600.    Elapsed: 0:07:55.
#   Batch 2,680  of  3,600.    Elapsed: 0:07:57.
#   Batch 2,690  of  3,600.    Elapsed: 0:07:58.
#   Batch 2,700  of  3,600.    Elapsed: 0:08:00.
#   Batch 2,710  of  3,600.    Elapsed: 0:08:02.
#   Batch 2,720  of  3,600.    Elapsed: 0:08:04.
#   Batch 2,730  of  3,600.    Elapsed: 0:08:05.
#   Batch 2,740  of  3,600.    Elapsed: 0:08:07.
#   Batch 2,750  of  3,600.    Elapsed: 0:08:09.
#   Batch 2,760  of  3,600.    Elapsed: 0:08:11.
#   Batch 2,770  of  3,600.    Elapsed: 0:08:13.
#   Batch 2,780  of  3,600.    Elapsed: 0:08:14.
#   Batch 2,790  of  3,600.    Elapsed: 0:08:16.
#   Batch 2,800  of  3,600.    Elapsed: 0:08:18.
#   Batch 2,810  of  3,600.    Elapsed: 0:08:20.
#   Batch 2,820  of  3,600.    Elapsed: 0:08:21.
#   Batch 2,830  of  3,600.    Elapsed: 0:08:23.
#   Batch 2,840  of  3,600.    Elapsed: 0:08:25.
#   Batch 2,850  of  3,600.    Elapsed: 0:08:27.
#   Batch 2,860  of  3,600.    Elapsed: 0:08:29.
#   Batch 2,870  of  3,600.    Elapsed: 0:08:30.
#   Batch 2,880  of  3,600.    Elapsed: 0:08:32.
#   Batch 2,890  of  3,600.    Elapsed: 0:08:34.
#   Batch 2,900  of  3,600.    Elapsed: 0:08:36.
#   Batch 2,910  of  3,600.    Elapsed: 0:08:37.
#   Batch 2,920  of  3,600.    Elapsed: 0:08:39.
#   Batch 2,930  of  3,600.    Elapsed: 0:08:41.
#   Batch 2,940  of  3,600.    Elapsed: 0:08:43.
#   Batch 2,950  of  3,600.    Elapsed: 0:08:45.
# ...
#   Batch   230  of  3,600.    Elapsed: 0:00:41.
#   Batch   240  of  3,600.    Elapsed: 0:00:43.
#   Batch   250  of  3,600.    Elapsed: 0:00:44.
#   Batch   260  of  3,600.    Elapsed: 0:00:46.
#   Batch   270  of  3,600.    Elapsed: 0:00:48.
#   Batch   280  of  3,600.    Elapsed: 0:00:50.
#   Batch   290  of  3,600.    Elapsed: 0:00:52.
#   Batch   300  of  3,600.    Elapsed: 0:00:53.
#   Batch   310  of  3,600.    Elapsed: 0:00:55.
#   Batch   320  of  3,600.    Elapsed: 0:00:57.
#   Batch   330  of  3,600.    Elapsed: 0:00:59.
#   Batch   340  of  3,600.    Elapsed: 0:01:00.
#   Batch   350  of  3,600.    Elapsed: 0:01:02.
#   Batch   360  of  3,600.    Elapsed: 0:01:04.
#   Batch   370  of  3,600.    Elapsed: 0:01:06.
#   Batch   380  of  3,600.    Elapsed: 0:01:08.
#   Batch   390  of  3,600.    Elapsed: 0:01:09.
#   Batch   400  of  3,600.    Elapsed: 0:01:11.
#   Batch   410  of  3,600.    Elapsed: 0:01:13.
#   Batch   420  of  3,600.    Elapsed: 0:01:15.
#   Batch   430  of  3,600.    Elapsed: 0:01:16.
#   Batch   440  of  3,600.    Elapsed: 0:01:18.
#   Batch   450  of  3,600.    Elapsed: 0:01:20.
#   Batch   460  of  3,600.    Elapsed: 0:01:22.
#   Batch   470  of  3,600.    Elapsed: 0:01:24.
#   Batch   480  of  3,600.    Elapsed: 0:01:25.
#   Batch   490  of  3,600.    Elapsed: 0:01:27.
#   Batch   500  of  3,600.    Elapsed: 0:01:29.
#   Batch   510  of  3,600.    Elapsed: 0:01:31.
#   Batch   520  of  3,600.    Elapsed: 0:01:32.
#   Batch   530  of  3,600.    Elapsed: 0:01:34.
#   Batch   540  of  3,600.    Elapsed: 0:01:36.
#   Batch   550  of  3,600.    Elapsed: 0:01:38.
#   Batch   560  of  3,600.    Elapsed: 0:01:40.
#   Batch   570  of  3,600.    Elapsed: 0:01:41.
#   Batch   580  of  3,600.    Elapsed: 0:01:43.
#   Batch   590  of  3,600.    Elapsed: 0:01:45.
#   Batch   600  of  3,600.    Elapsed: 0:01:47.
#   Batch   610  of  3,600.    Elapsed: 0:01:48.
#   Batch   620  of  3,600.    Elapsed: 0:01:50.
#   Batch   630  of  3,600.    Elapsed: 0:01:52.
#   Batch   640  of  3,600.    Elapsed: 0:01:54.
#   Batch   650  of  3,600.    Elapsed: 0:01:56.
#   Batch   660  of  3,600.    Elapsed: 0:01:57.
#   Batch   670  of  3,600.    Elapsed: 0:01:59.
#   Batch   680  of  3,600.    Elapsed: 0:02:01.
#   Batch   690  of  3,600.    Elapsed: 0:02:03.
#   Batch   700  of  3,600.    Elapsed: 0:02:04.
#   Batch   710  of  3,600.    Elapsed: 0:02:06.
#   Batch   720  of  3,600.    Elapsed: 0:02:08.
#   Batch   730  of  3,600.    Elapsed: 0:02:10.
#   Batch   740  of  3,600.    Elapsed: 0:02:12.
#   Batch   750  of  3,600.    Elapsed: 0:02:13.
#   Batch   760  of  3,600.    Elapsed: 0:02:15.
#   Batch   770  of  3,600.    Elapsed: 0:02:17.
#   Batch   780  of  3,600.    Elapsed: 0:02:19.
#   Batch   790  of  3,600.    Elapsed: 0:02:20.
#   Batch   800  of  3,600.    Elapsed: 0:02:22.
#   Batch   810  of  3,600.    Elapsed: 0:02:24.
#   Batch   820  of  3,600.    Elapsed: 0:02:26.
#   Batch   830  of  3,600.    Elapsed: 0:02:28.
#   Batch   840  of  3,600.    Elapsed: 0:02:29.
#   Batch   850  of  3,600.    Elapsed: 0:02:31.
#   Batch   860  of  3,600.    Elapsed: 0:02:33.
#   Batch   870  of  3,600.    Elapsed: 0:02:35.
#   Batch   880  of  3,600.    Elapsed: 0:02:36.
#   Batch   890  of  3,600.    Elapsed: 0:02:38.
#   Batch   900  of  3,600.    Elapsed: 0:02:40.
#   Batch   910  of  3,600.    Elapsed: 0:02:42.
#   Batch   920  of  3,600.    Elapsed: 0:02:44.
#   Batch   930  of  3,600.    Elapsed: 0:02:45.
#   Batch   940  of  3,600.    Elapsed: 0:02:47.
#   Batch   950  of  3,600.    Elapsed: 0:02:49.
#   Batch   960  of  3,600.    Elapsed: 0:02:51.
#   Batch   970  of  3,600.    Elapsed: 0:02:52.
#   Batch   980  of  3,600.    Elapsed: 0:02:54.
#   Batch   990  of  3,600.    Elapsed: 0:02:56.
#   Batch 1,000  of  3,600.    Elapsed: 0:02:58.
#   Batch 1,010  of  3,600.    Elapsed: 0:03:00.
#   Batch 1,020  of  3,600.    Elapsed: 0:03:01.
#   Batch 1,030  of  3,600.    Elapsed: 0:03:03.
#   Batch 1,040  of  3,600.    Elapsed: 0:03:05.
#   Batch 1,050  of  3,600.    Elapsed: 0:03:07.
#   Batch 1,060  of  3,600.    Elapsed: 0:03:08.
#   Batch 1,070  of  3,600.    Elapsed: 0:03:10.
#   Batch 1,080  of  3,600.    Elapsed: 0:03:12.
#   Batch 1,090  of  3,600.    Elapsed: 0:03:14.
#   Batch 1,100  of  3,600.    Elapsed: 0:03:16.
#   Batch 1,110  of  3,600.    Elapsed: 0:03:17.
#   Batch 1,120  of  3,600.    Elapsed: 0:03:19.
#   Batch 1,130  of  3,600.    Elapsed: 0:03:21.
#   Batch 1,140  of  3,600.    Elapsed: 0:03:23.
#   Batch 1,150  of  3,600.    Elapsed: 0:03:24.
#   Batch 1,160  of  3,600.    Elapsed: 0:03:26.
#   Batch 1,170  of  3,600.    Elapsed: 0:03:28.
#   Batch 1,180  of  3,600.    Elapsed: 0:03:30.
#   Batch 1,190  of  3,600.    Elapsed: 0:03:32.
#   Batch 1,200  of  3,600.    Elapsed: 0:03:33.
#   Batch 1,210  of  3,600.    Elapsed: 0:03:35.
#   Batch 1,220  of  3,600.    Elapsed: 0:03:37.
#   Batch 1,230  of  3,600.    Elapsed: 0:03:39.
#   Batch 1,240  of  3,600.    Elapsed: 0:03:40.
#   Batch 1,250  of  3,600.    Elapsed: 0:03:42.
#   Batch 1,260  of  3,600.    Elapsed: 0:03:44.
#   Batch 1,270  of  3,600.    Elapsed: 0:03:46.
#   Batch 1,280  of  3,600.    Elapsed: 0:03:48.
#   Batch 1,290  of  3,600.    Elapsed: 0:03:49.
#   Batch 1,300  of  3,600.    Elapsed: 0:03:51.
#   Batch 1,310  of  3,600.    Elapsed: 0:03:53.
#   Batch 1,320  of  3,600.    Elapsed: 0:03:55.
#   Batch 1,330  of  3,600.    Elapsed: 0:03:56.
#   Batch 1,340  of  3,600.    Elapsed: 0:03:58.
#   Batch 1,350  of  3,600.    Elapsed: 0:04:00.
#   Batch 1,360  of  3,600.    Elapsed: 0:04:02.
#   Batch 1,370  of  3,600.    Elapsed: 0:04:04.
#   Batch 1,380  of  3,600.    Elapsed: 0:04:05.
#   Batch 1,390  of  3,600.    Elapsed: 0:04:07.
#   Batch 1,400  of  3,600.    Elapsed: 0:04:09.
#   Batch 1,410  of  3,600.    Elapsed: 0:04:11.
#   Batch 1,420  of  3,600.    Elapsed: 0:04:12.
#   Batch 1,430  of  3,600.    Elapsed: 0:04:14.
#   Batch 1,440  of  3,600.    Elapsed: 0:04:16.
#   Batch 1,450  of  3,600.    Elapsed: 0:04:18.
#   Batch 1,460  of  3,600.    Elapsed: 0:04:20.
#   Batch 1,470  of  3,600.    Elapsed: 0:04:21.
#   Batch 1,480  of  3,600.    Elapsed: 0:04:23.
#   Batch 1,490  of  3,600.    Elapsed: 0:04:25.
#   Batch 1,500  of  3,600.    Elapsed: 0:04:27.
#   Batch 1,510  of  3,600.    Elapsed: 0:04:28.
#   Batch 1,520  of  3,600.    Elapsed: 0:04:30.
#   Batch 1,530  of  3,600.    Elapsed: 0:04:32.
#   Batch 1,540  of  3,600.    Elapsed: 0:04:34.
#   Batch 1,550  of  3,600.    Elapsed: 0:04:36.
#   Batch 1,560  of  3,600.    Elapsed: 0:04:37.
#   Batch 1,570  of  3,600.    Elapsed: 0:04:39.
#   Batch 1,580  of  3,600.    Elapsed: 0:04:41.
#   Batch 1,590  of  3,600.    Elapsed: 0:04:43.
#   Batch 1,600  of  3,600.    Elapsed: 0:04:44.
#   Batch 1,610  of  3,600.    Elapsed: 0:04:46.
#   Batch 1,620  of  3,600.    Elapsed: 0:04:48.
#   Batch 1,630  of  3,600.    Elapsed: 0:04:50.
#   Batch 1,640  of  3,600.    Elapsed: 0:04:52.
#   Batch 1,650  of  3,600.    Elapsed: 0:04:53.
#   Batch 1,660  of  3,600.    Elapsed: 0:04:55.
#   Batch 1,670  of  3,600.    Elapsed: 0:04:57.
#   Batch 1,680  of  3,600.    Elapsed: 0:04:59.
#   Batch 1,690  of  3,600.    Elapsed: 0:05:00.
#   Batch 1,700  of  3,600.    Elapsed: 0:05:02.
#   Batch 1,710  of  3,600.    Elapsed: 0:05:04.
#   Batch 1,720  of  3,600.    Elapsed: 0:05:06.
#   Batch 1,730  of  3,600.    Elapsed: 0:05:08.
#   Batch 1,740  of  3,600.    Elapsed: 0:05:09.
#   Batch 1,750  of  3,600.    Elapsed: 0:05:11.
#   Batch 1,760  of  3,600.    Elapsed: 0:05:13.
#   Batch 1,770  of  3,600.    Elapsed: 0:05:15.
#   Batch 1,780  of  3,600.    Elapsed: 0:05:16.
#   Batch 1,790  of  3,600.    Elapsed: 0:05:18.
#   Batch 1,800  of  3,600.    Elapsed: 0:05:20.
#   Batch 1,810  of  3,600.    Elapsed: 0:05:22.
#   Batch 1,820  of  3,600.    Elapsed: 0:05:24.
#   Batch 1,830  of  3,600.    Elapsed: 0:05:25.
#   Batch 1,840  of  3,600.    Elapsed: 0:05:27.
#   Batch 1,850  of  3,600.    Elapsed: 0:05:29.
#   Batch 1,860  of  3,600.    Elapsed: 0:05:31.
#   Batch 1,870  of  3,600.    Elapsed: 0:05:32.
#   Batch 1,880  of  3,600.    Elapsed: 0:05:34.
#   Batch 1,890  of  3,600.    Elapsed: 0:05:36.
#   Batch 1,900  of  3,600.    Elapsed: 0:05:38.
#   Batch 1,910  of  3,600.    Elapsed: 0:05:40.
#   Batch 1,920  of  3,600.    Elapsed: 0:05:41.
#   Batch 1,930  of  3,600.    Elapsed: 0:05:43.
#   Batch 1,940  of  3,600.    Elapsed: 0:05:45.
#   Batch 1,950  of  3,600.    Elapsed: 0:05:47.
#   Batch 1,960  of  3,600.    Elapsed: 0:05:48.
#   Batch 1,970  of  3,600.    Elapsed: 0:05:50.
#   Batch 1,980  of  3,600.    Elapsed: 0:05:52.
#   Batch 1,990  of  3,600.    Elapsed: 0:05:54.
#   Batch 2,000  of  3,600.    Elapsed: 0:05:56.
#   Batch 2,010  of  3,600.    Elapsed: 0:05:57.
#   Batch 2,020  of  3,600.    Elapsed: 0:05:59.
#   Batch 2,030  of  3,600.    Elapsed: 0:06:01.
#   Batch 2,040  of  3,600.    Elapsed: 0:06:03.
#   Batch 2,050  of  3,600.    Elapsed: 0:06:05.
#   Batch 2,060  of  3,600.    Elapsed: 0:06:06.
#   Batch 2,070  of  3,600.    Elapsed: 0:06:08.
#   Batch 2,080  of  3,600.    Elapsed: 0:06:10.
#   Batch 2,090  of  3,600.    Elapsed: 0:06:12.
#   Batch 2,100  of  3,600.    Elapsed: 0:06:13.
#   Batch 2,110  of  3,600.    Elapsed: 0:06:15.
#   Batch 2,120  of  3,600.    Elapsed: 0:06:17.
#   Batch 2,130  of  3,600.    Elapsed: 0:06:19.
#   Batch 2,140  of  3,600.    Elapsed: 0:06:21.
#   Batch 2,150  of  3,600.    Elapsed: 0:06:22.
#   Batch 2,160  of  3,600.    Elapsed: 0:06:24.
#   Batch 2,170  of  3,600.    Elapsed: 0:06:26.
#   Batch 2,180  of  3,600.    Elapsed: 0:06:28.
#   Batch 2,190  of  3,600.    Elapsed: 0:06:29.
#   Batch 2,200  of  3,600.    Elapsed: 0:06:31.
#   Batch 2,210  of  3,600.    Elapsed: 0:06:33.
#   Batch 2,220  of  3,600.    Elapsed: 0:06:35.
#   Batch 2,230  of  3,600.    Elapsed: 0:06:37.
#   Batch 2,240  of  3,600.    Elapsed: 0:06:38.
#   Batch 2,250  of  3,600.    Elapsed: 0:06:40.
#   Batch 2,260  of  3,600.    Elapsed: 0:06:42.
#   Batch 2,270  of  3,600.    Elapsed: 0:06:44.
#   Batch 2,280  of  3,600.    Elapsed: 0:06:45.
#   Batch 2,290  of  3,600.    Elapsed: 0:06:47.
#   Batch 2,300  of  3,600.    Elapsed: 0:06:49.
#   Batch 2,310  of  3,600.    Elapsed: 0:06:51.
#   Batch 2,320  of  3,600.    Elapsed: 0:06:53.
#   Batch 2,330  of  3,600.    Elapsed: 0:06:54.
#   Batch 2,340  of  3,600.    Elapsed: 0:06:56.
#   Batch 2,350  of  3,600.    Elapsed: 0:06:58.
#   Batch 2,360  of  3,600.    Elapsed: 0:07:00.
#   Batch 2,370  of  3,600.    Elapsed: 0:07:01.
#   Batch 2,380  of  3,600.    Elapsed: 0:07:03.
#   Batch 2,390  of  3,600.    Elapsed: 0:07:05.
#   Batch 2,400  of  3,600.    Elapsed: 0:07:07.
#   Batch 2,410  of  3,600.    Elapsed: 0:07:09.
#   Batch 2,420  of  3,600.    Elapsed: 0:07:10.
#   Batch 2,430  of  3,600.    Elapsed: 0:07:12.
#   Batch 2,440  of  3,600.    Elapsed: 0:07:14.
#   Batch 2,450  of  3,600.    Elapsed: 0:07:16.
#   Batch 2,460  of  3,600.    Elapsed: 0:07:17.
#   Batch 2,470  of  3,600.    Elapsed: 0:07:19.
#   Batch 2,480  of  3,600.    Elapsed: 0:07:21.
#   Batch 2,490  of  3,600.    Elapsed: 0:07:23.
#   Batch 2,500  of  3,600.    Elapsed: 0:07:25.
#   Batch 2,510  of  3,600.    Elapsed: 0:07:26.
#   Batch 2,520  of  3,600.    Elapsed: 0:07:28.
#   Batch 2,530  of  3,600.    Elapsed: 0:07:30.
#   Batch 2,540  of  3,600.    Elapsed: 0:07:32.
#   Batch 2,550  of  3,600.    Elapsed: 0:07:33.
#   Batch 2,560  of  3,600.    Elapsed: 0:07:35.
#   Batch 2,570  of  3,600.    Elapsed: 0:07:37.
#   Batch 2,580  of  3,600.    Elapsed: 0:07:39.
#   Batch 2,590  of  3,600.    Elapsed: 0:07:41.
#   Batch 2,600  of  3,600.    Elapsed: 0:07:42.
#   Batch 2,610  of  3,600.    Elapsed: 0:07:44.
#   Batch 2,620  of  3,600.    Elapsed: 0:07:46.
#   Batch 2,630  of  3,600.    Elapsed: 0:07:48.
#   Batch 2,640  of  3,600.    Elapsed: 0:07:49.
#   Batch 2,650  of  3,600.    Elapsed: 0:07:51.
#   Batch 2,660  of  3,600.    Elapsed: 0:07:53.
#   Batch 2,670  of  3,600.    Elapsed: 0:07:55.
#   Batch 2,680  of  3,600.    Elapsed: 0:07:57.
#   Batch 2,690  of  3,600.    Elapsed: 0:07:58.
#   Batch 2,700  of  3,600.    Elapsed: 0:08:00.
#   Batch 2,710  of  3,600.    Elapsed: 0:08:02.
#   Batch 2,720  of  3,600.    Elapsed: 0:08:04.
#   Batch 2,730  of  3,600.    Elapsed: 0:08:05.
#   Batch 2,740  of  3,600.    Elapsed: 0:08:07.
#   Batch 2,750  of  3,600.    Elapsed: 0:08:09.
#   Batch 2,760  of  3,600.    Elapsed: 0:08:11.
#   Batch 2,770  of  3,600.    Elapsed: 0:08:13.
#   Batch 2,780  of  3,600.    Elapsed: 0:08:14.
#   Batch 2,790  of  3,600.    Elapsed: 0:08:16.
#   Batch 2,800  of  3,600.    Elapsed: 0:08:18.
#   Batch 2,810  of  3,600.    Elapsed: 0:08:20.
#   Batch 2,820  of  3,600.    Elapsed: 0:08:21.
#   Batch 2,830  of  3,600.    Elapsed: 0:08:23.
#   Batch 2,840  of  3,600.    Elapsed: 0:08:25.
#   Batch 2,850  of  3,600.    Elapsed: 0:08:27.
#   Batch 2,860  of  3,600.    Elapsed: 0:08:29.
#   Batch 2,870  of  3,600.    Elapsed: 0:08:30.
#   Batch 2,880  of  3,600.    Elapsed: 0:08:32.
#   Batch 2,890  of  3,600.    Elapsed: 0:08:34.
#   Batch 2,900  of  3,600.    Elapsed: 0:08:36.
#   Batch 2,910  of  3,600.    Elapsed: 0:08:37.
#   Batch 2,920  of  3,600.    Elapsed: 0:08:39.
#   Batch 2,930  of  3,600.    Elapsed: 0:08:41.
#   Batch 2,940  of  3,600.    Elapsed: 0:08:43.
#   Batch 2,950  of  3,600.    Elapsed: 0:08:45.
#   Batch 2,960  of  3,600.    Elapsed: 0:08:46.
#   Batch 2,970  of  3,600.    Elapsed: 0:08:48.
#   Batch 2,980  of  3,600.    Elapsed: 0:08:50.
#   Batch 2,990  of  3,600.    Elapsed: 0:08:52.
#   Batch 3,000  of  3,600.    Elapsed: 0:08:53.
#   Batch 3,010  of  3,600.    Elapsed: 0:08:55.
#   Batch 3,020  of  3,600.    Elapsed: 0:08:57.
#   Batch 3,030  of  3,600.    Elapsed: 0:08:59.
#   Batch 3,040  of  3,600.    Elapsed: 0:09:01.
#   Batch 3,050  of  3,600.    Elapsed: 0:09:02.
#   Batch 3,060  of  3,600.    Elapsed: 0:09:04.
#   Batch 3,070  of  3,600.    Elapsed: 0:09:06.
#   Batch 3,080  of  3,600.    Elapsed: 0:09:08.
#   Batch 3,090  of  3,600.    Elapsed: 0:09:09.
#   Batch 3,100  of  3,600.    Elapsed: 0:09:11.
#   Batch 3,110  of  3,600.    Elapsed: 0:09:13.
#   Batch 3,120  of  3,600.    Elapsed: 0:09:15.
#   Batch 3,130  of  3,600.    Elapsed: 0:09:17.
#   Batch 3,140  of  3,600.    Elapsed: 0:09:18.
#   Batch 3,150  of  3,600.    Elapsed: 0:09:20.
#   Batch 3,160  of  3,600.    Elapsed: 0:09:22.
#   Batch 3,170  of  3,600.    Elapsed: 0:09:24.
#   Batch 3,180  of  3,600.    Elapsed: 0:09:25.
#   Batch 3,190  of  3,600.    Elapsed: 0:09:27.
#   Batch 3,200  of  3,600.    Elapsed: 0:09:29.
#   Batch 3,210  of  3,600.    Elapsed: 0:09:31.
#   Batch 3,220  of  3,600.    Elapsed: 0:09:33.
#   Batch 3,230  of  3,600.    Elapsed: 0:09:34.
#   Batch 3,240  of  3,600.    Elapsed: 0:09:36.
#   Batch 3,250  of  3,600.    Elapsed: 0:09:38.
#   Batch 3,260  of  3,600.    Elapsed: 0:09:40.
#   Batch 3,270  of  3,600.    Elapsed: 0:09:41.
#   Batch 3,280  of  3,600.    Elapsed: 0:09:43.
#   Batch 3,290  of  3,600.    Elapsed: 0:09:45.
#   Batch 3,300  of  3,600.    Elapsed: 0:09:47.
#   Batch 3,310  of  3,600.    Elapsed: 0:09:49.
#   Batch 3,320  of  3,600.    Elapsed: 0:09:50.
#   Batch 3,330  of  3,600.    Elapsed: 0:09:52.
#   Batch 3,340  of  3,600.    Elapsed: 0:09:54.
#   Batch 3,350  of  3,600.    Elapsed: 0:09:56.
#   Batch 3,360  of  3,600.    Elapsed: 0:09:57.
#   Batch 3,370  of  3,600.    Elapsed: 0:09:59.
#   Batch 3,380  of  3,600.    Elapsed: 0:10:01.
#   Batch 3,390  of  3,600.    Elapsed: 0:10:03.
#   Batch 3,400  of  3,600.    Elapsed: 0:10:05.
#   Batch 3,410  of  3,600.    Elapsed: 0:10:06.
#   Batch 3,420  of  3,600.    Elapsed: 0:10:08.
#   Batch 3,430  of  3,600.    Elapsed: 0:10:10.
#   Batch 3,440  of  3,600.    Elapsed: 0:10:12.
#   Batch 3,450  of  3,600.    Elapsed: 0:10:13.
#   Batch 3,460  of  3,600.    Elapsed: 0:10:15.
#   Batch 3,470  of  3,600.    Elapsed: 0:10:17.
#   Batch 3,480  of  3,600.    Elapsed: 0:10:19.
#   Batch 3,490  of  3,600.    Elapsed: 0:10:21.
#   Batch 3,500  of  3,600.    Elapsed: 0:10:22.
#   Batch 3,510  of  3,600.    Elapsed: 0:10:24.
#   Batch 3,520  of  3,600.    Elapsed: 0:10:26.
#   Batch 3,530  of  3,600.    Elapsed: 0:10:28.
#   Batch 3,540  of  3,600.    Elapsed: 0:10:29.
#   Batch 3,550  of  3,600.    Elapsed: 0:10:31.
#   Batch 3,560  of  3,600.    Elapsed: 0:10:33.
#   Batch 3,570  of  3,600.    Elapsed: 0:10:35.
#   Batch 3,580  of  3,600.    Elapsed: 0:10:37.
#   Batch 3,590  of  3,600.    Elapsed: 0:10:38.
#
#   Average training loss: 0.64
#   Training epcoh took: 0:10:40
#
# Running Validation...
#   Accuracy: 0.59
#   Validation took: 0:00:19
#
# Training complete!

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

# Plot the learning curve.
plt.plot(loss_values, 'b-o')

# Label the plot.
plt.title("Training loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.show()

# %% [markdown]
# ### Evaluation

# %%
print('Predicting labels for {:,} test sentences...'.format(len(test_inputs)))

# Put model in evaluation mode
model.eval()

# Tracking variables 
predictions, true_labels = [], []

# Predict 
total_correct = 0
for idx, batch in enumerate(test_dataloader):
    
    print("Batch {}".format(idx + 1))
    
    # Add batch to device
    batch = tuple(t.to(device) for t in batch)
  
    # Unpack the inputs from our dataloader
    b_input_ids, b_input_mask, b_labels = batch
  
    # Telling the model not to compute or store gradients, saving memory and 
    # speeding up prediction
    with torch.no_grad():
        # Forward pass, calculate logit predictions
        outputs = model(b_input_ids, token_type_ids=None, 
                        attention_mask=b_input_mask)

    # Get the prediction probability
    logits = outputs[0]
    
    # Get the prediction label
    pred = torch.argmax(logits, dim=1)
   
    # Get the number of correct predictions in this batch
    batch_correct = (pred == b_labels).sum().item()
    print("Batch correct = {}\n".format(batch_correct))
    
    # Accumulate the number of correct predictions over all batches
    total_correct += batch_correct
    
    # Append the predicted labels and true labels for this batch
    predictions.append(pred.cpu().numpy())
    true_labels.append(b_labels.cpu().numpy())
    

print('DONE.')
print("Total correct = ", total_correct)
print("Test accuracy = {0:.2f}".format(total_correct / len(test_inputs)))

# Concatenate the predicted labels and true labels over all batches
predictions = np.concatenate(predictions, axis=0)
true_labels = np.concatenate(true_labels, axis=0)

# Print classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(true_labels, predictions))
print(confusion_matrix(true_labels, predictions))
# Out:
# Predicting labels for 16,000 test sentences...
# Batch 1
# Batch correct = 12
#
# Batch 2
# Batch correct = 7
#
# Batch 3
# Batch correct = 10
#
# Batch 4
# Batch correct = 8
#
# Batch 5
# Batch correct = 12
#
# Batch 6
# Batch correct = 10
#
# Batch 7
# Batch correct = 12
#
# Batch 8
# Batch correct = 10
#
# Batch 9
# Batch correct = 11
#
# Batch 10
# Batch correct = 14
#
# Batch 11
# Batch correct = 11
#
# Batch 12
# Batch correct = 10
#
# Batch 13
# Batch correct = 6
#
# Batch 14
# Batch correct = 12
#
# Batch 15
# Batch correct = 10
#
# Batch 16
# Batch correct = 11
#
# Batch 17
# Batch correct = 12
#
# Batch 18
# Batch correct = 11
#
# Batch 19
# Batch correct = 7
#
# Batch 20
# Batch correct = 9
#
# Batch 21
# Batch correct = 8
#
# Batch 22
# Batch correct = 7
#
# Batch 23
# Batch correct = 11
#
# Batch 24
# Batch correct = 10
#
# Batch 25
# Batch correct = 9
#
# Batch 26
# Batch correct = 11
#
# Batch 27
# Batch correct = 12
#
# Batch 28
# Batch correct = 12
#
# Batch 29
# Batch correct = 8
#
# Batch 30
# Batch correct = 9
#
# Batch 31
# Batch correct = 10
#
# Batch 32
# Batch correct = 13
#
# Batch 33
# Batch correct = 11
#
# Batch 34
# Batch correct = 9
#
# Batch 35
# Batch correct = 9
#
# Batch 36
# Batch correct = 8
#
# Batch 37
# Batch correct = 7
#
# Batch 38
# Batch correct = 12
#
# Batch 39
# Batch correct = 11
#
# Batch 40
# Batch correct = 10
#
# Batch 41
# Batch correct = 11
#
# Batch 42
# Batch correct = 11
#
# Batch 43
# Batch correct = 7
#
# Batch 44
# Batch correct = 11
#
# Batch 45
# Batch correct = 10
#
# Batch 46
# Batch correct = 7
#
# Batch 47
# Batch correct = 9
#
# Batch 48
# Batch correct = 9
#
# Batch 49
# Batch correct = 9
#
# Batch 50
# Batch correct = 9
#
# Batch 51
# Batch correct = 9
#
# Batch 52
# Batch correct = 8
#
# Batch 53
# Batch correct = 10
#
# Batch 54
# Batch correct = 12
#
# Batch 55
# Batch correct = 7
#
# Batch 56
# Batch correct = 10
#
# Batch 57
# Batch correct = 12
#
# Batch 58
# Batch correct = 12
#
# Batch 59
# Batch correct = 12
#
# Batch 60
# Batch correct = 11
#
# Batch 61
# Batch correct = 7
#
# Batch 62
# Batch correct = 13
#
# Batch 63
# Batch correct = 10
#
# Batch 64
# Batch correct = 8
#
# Batch 65
# Batch correct = 10
#
# Batch 66
# Batch correct = 9
#
# Batch 67
# Batch correct = 10
#
# Batch 68
# Batch correct = 7
#
# Batch 69
# Batch correct = 8
#
# Batch 70
# Batch correct = 9
#
# Batch 71
# Batch correct = 8
#
# Batch 72
# Batch correct = 11
#
# Batch 73
# Batch correct = 9
#
# Batch 74
# Batch correct = 10
#
# Batch 75
# Batch correct = 8
#
# Batch 76
# Batch correct = 10
#
# Batch 77
# Batch correct = 10
#
# Batch 78
# Batch correct = 8
#
# Batch 79
# Batch correct = 10
#
# Batch 80
# Batch correct = 9
#
# Batch 81
# Batch correct = 13
#
# Batch 82
# Batch correct = 10
#
# Batch 83
# Batch correct = 10
#
# Batch 84
# Batch correct = 7
#
# Batch 85
# Batch correct = 8
#
# Batch 86
# Batch correct = 9
#
# Batch 87
# Batch correct = 11
#
# Batch 88
# Batch correct = 11
#
# Batch 89
# Batch correct = 9
#
# Batch 90
# Batch correct = 9
#
# Batch 91
# Batch correct = 11
#
# Batch 92
# Batch correct = 10
#
# Batch 93
# Batch correct = 12
#
# Batch 94
# Batch correct = 10
#
# Batch 95
# Batch correct = 13
#
# Batch 96
# Batch correct = 8
#
# Batch 97
# Batch correct = 9
#
# Batch 98
# Batch correct = 10
#
# Batch 99
# Batch correct = 11
#
# Batch 100
# Batch correct = 10
#
# Batch 101
# Batch correct = 9
#
# Batch 102
# Batch correct = 12
#
# Batch 103
# Batch correct = 11
#
# Batch 104
# Batch correct = 8
#
# Batch 105
# Batch correct = 10
#
# Batch 106
# Batch correct = 8
#
# Batch 107
# Batch correct = 11
#
# Batch 108
# Batch correct = 12
#
# Batch 109
# Batch correct = 6
#
# Batch 110
# Batch correct = 10
#
# Batch 111
# Batch correct = 8
#
# Batch 112
# Batch correct = 12
#
# Batch 113
# Batch correct = 10
#
# Batch 114
# Batch correct = 9
#
# Batch 115
# Batch correct = 6
#
# Batch 116
# Batch correct = 12
#
# Batch 117
# Batch correct = 10
#
# Batch 118
# Batch correct = 10
#
# Batch 119
# Batch correct = 14
#
# Batch 120
# Batch correct = 10
#
# Batch 121
# Batch correct = 12
#
# Batch 122
# Batch correct = 13
#
# Batch 123
# Batch correct = 9
#
# Batch 124
# Batch correct = 8
#
# Batch 125
# Batch correct = 9
#
# Batch 126
# Batch correct = 8
#
# Batch 127
# Batch correct = 9
#
# Batch 128
# Batch correct = 12
#
# Batch 129
# Batch correct = 11
#
# Batch 130
# Batch correct = 8
#
# Batch 131
# Batch correct = 10
#
# Batch 132
# Batch correct = 8
#
# Batch 133
# Batch correct = 9
#
# Batch 134
# Batch correct = 8
#
# Batch 135
# Batch correct = 9
#
# Batch 136
# Batch correct = 10
#
# Batch 137
# Batch correct = 11
#
# Batch 138
# Batch correct = 11
#
# Batch 139
# Batch correct = 11
#
# Batch 140
# Batch correct = 9
#
# Batch 141
# Batch correct = 10
#
# Batch 142
# Batch correct = 9
#
# Batch 143
# Batch correct = 11
#
# Batch 144
# Batch correct = 13
#
# Batch 145
# Batch correct = 7
#
# Batch 146
# Batch correct = 13
#
# Batch 147
# Batch correct = 11
#
# Batch 148
# Batch correct = 10
#
# Batch 149
# Batch correct = 13
#
# Batch 150
# Batch correct = 7
#
# Batch 151
# Batch correct = 9
#
# Batch 152
# Batch correct = 10
#
# Batch 153
# Batch correct = 12
#
# Batch 154
# Batch correct = 11
#
# Batch 155
# Batch correct = 10
#
# Batch 156
# Batch correct = 12
#
# Batch 157
# Batch correct = 7
#
# Batch 158
# Batch correct = 11
#
# Batch 159
# Batch correct = 13
#
# Batch 160
# Batch correct = 11
#
# Batch 161
# Batch correct = 8
#
# Batch 162
# Batch correct = 11
#
# Batch 163
# Batch correct = 10
#
# Batch 164
# Batch correct = 12
#
# Batch 165
# Batch correct = 10
#
# Batch 166
# Batch correct = 7
#
# Batch 167
# Batch correct = 7
#
# Batch 168
# Batch correct = 12
#
# Batch 169
# Batch correct = 9
#
# Batch 170
# Batch correct = 9
#
# Batch 171
# Batch correct = 6
#
# Batch 172
# Batch correct = 10
#
# Batch 173
# Batch correct = 9
#
# Batch 174
# Batch correct = 12
#
# Batch 175
# Batch correct = 9
#
# Batch 176
# Batch correct = 8
#
# Batch 177
# Batch correct = 9
#
# Batch 178
# Batch correct = 9
#
# Batch 179
# Batch correct = 11
#
# Batch 180
# Batch correct = 12
#
# Batch 181
# Batch correct = 10
#
# Batch 182
# Batch correct = 7
#
# Batch 183
# Batch correct = 10
#
# Batch 184
# Batch correct = 6
#
# Batch 185
# Batch correct = 11
#
# Batch 186
# Batch correct = 10
#
# Batch 187
# Batch correct = 10
#
# Batch 188
# Batch correct = 11
#
# Batch 189
# Batch correct = 12
#
# Batch 190
# Batch correct = 12
#
# Batch 191
# Batch correct = 11
#
# Batch 192
# Batch correct = 10
#
# Batch 193
# Batch correct = 8
#
# Batch 194
# Batch correct = 9
#
# Batch 195
# Batch correct = 12
#
# Batch 196
# Batch correct = 11
#
# Batch 197
# Batch correct = 8
#
# Batch 198
# Batch correct = 10
#
# Batch 199
# Batch correct = 10
#
# Batch 200
# Batch correct = 10
#
# Batch 201
# Batch correct = 10
#
# Batch 202
# Batch correct = 9
#
# Batch 203
# Batch correct = 13
#
# Batch 204
# Batch correct = 9
#
# Batch 205
# Batch correct = 13
#
# Batch 206
# Batch correct = 11
#
# Batch 207
# Batch correct = 10
#
# Batch 208
# Batch correct = 12
#
# Batch 209
# Batch correct = 9
#
# Batch 210
# Batch correct = 11
#
# Batch 211
# Batch correct = 7
#
# Batch 212
# Batch correct = 14
#
# Batch 213
# Batch correct = 14
#
# Batch 214
# Batch correct = 10
#
# Batch 215
# Batch correct = 11
#
# Batch 216
# Batch correct = 7
#
# Batch 217
# Batch correct = 15
#
# Batch 218
# Batch correct = 7
#
# Batch 219
# Batch correct = 8
#
# Batch 220
# Batch correct = 12
#
# Batch 221
# Batch correct = 8
#
# Batch 222
# Batch correct = 9
#
# Batch 223
# Batch correct = 9
#
# Batch 224
# Batch correct = 12
#
# Batch 225
# Batch correct = 12
#
# Batch 226
# Batch correct = 7
#
# Batch 227
# Batch correct = 11
#
# Batch 228
# Batch correct = 8
#
# Batch 229
# Batch correct = 8
#
# Batch 230
# Batch correct = 12
#
# Batch 231
# Batch correct = 8
#
# Batch 232
# Batch correct = 7
#
# Batch 233
# Batch correct = 12
#
# Batch 234
# Batch correct = 9
#
# Batch 235
# Batch correct = 3
#
# Batch 236
# Batch correct = 9
#
# Batch 237
# Batch correct = 9
#
# Batch 238
# Batch correct = 10
#
# Batch 239
# Batch correct = 9
#
# Batch 240
# Batch correct = 7
#
# Batch 241
# Batch correct = 15
#
# Batch 242
# Batch correct = 12
#
# Batch 243
# Batch correct = 11
#
# Batch 244
# Batch correct = 11
#
# Batch 245
# Batch correct = 12
#
# Batch 246
# Batch correct = 7
#
# Batch 247
# Batch correct = 11
#
# Batch 248
# Batch correct = 7
#
# Batch 249
# Batch correct = 11
#
# Batch 250
# Batch correct = 6
#
# Batch 251
# Batch correct = 10
#
# Batch 252
# Batch correct = 10
#
# Batch 253
# Batch correct = 10
#
# Batch 254
# Batch correct = 7
#
# Batch 255
# Batch correct = 12
#
# Batch 256
# Batch correct = 11
#
# Batch 257
# Batch correct = 13
#
# Batch 258
# Batch correct = 11
#
# Batch 259
# Batch correct = 12
#
# Batch 260
# Batch correct = 9
#
# Batch 261
# Batch correct = 8
#
# Batch 262
# Batch correct = 10
#
# Batch 263
# Batch correct = 10
#
# Batch 264
# Batch correct = 10
#
# Batch 265
# Batch correct = 7
#
# Batch 266
# Batch correct = 8
#
# Batch 267
# Batch correct = 8
#
# Batch 268
# Batch correct = 11
#
# Batch 269
# Batch correct = 12
#
# Batch 270
# Batch correct = 8
#
# Batch 271
# Batch correct = 12
#
# Batch 272
# Batch correct = 11
#
# Batch 273
# Batch correct = 11
#
# Batch 274
# Batch correct = 10
#
# Batch 275
# Batch correct = 11
#
# Batch 276
# Batch correct = 11
#
# Batch 277
# Batch correct = 7
#
# Batch 278
# Batch correct = 10
#
# Batch 279
# Batch correct = 10
#
# Batch 280
# Batch correct = 10
#
# Batch 281
# Batch correct = 9
#
# Batch 282
# Batch correct = 11
#
# Batch 283
# Batch correct = 8
#
# Batch 284
# Batch correct = 5
#
# Batch 285
# Batch correct = 8
#
# Batch 286
# Batch correct = 7
#
# Batch 287
# Batch correct = 12
#
# Batch 288
# Batch correct = 8
#
# Batch 289
# Batch correct = 7
#
# Batch 290
# Batch correct = 7
#
# Batch 291
# Batch correct = 11
#
# Batch 292
# Batch correct = 9
#
# Batch 293
# Batch correct = 10
#
# Batch 294
# Batch correct = 11
#
# Batch 295
# Batch correct = 7
#
# Batch 296
# Batch correct = 9
#
# Batch 297
# Batch correct = 11
#
# Batch 298
# Batch correct = 12
#
# Batch 299
# Batch correct = 10
#
# Batch 300
# Batch correct = 9
#
# Batch 301
# Batch correct = 8
#
# Batch 302
# Batch correct = 6
#
# Batch 303
# Batch correct = 9
#
# Batch 304
# Batch correct = 10
#
# Batch 305
# Batch correct = 10
#
# Batch 306
# Batch correct = 8
#
# Batch 307
# Batch correct = 6
#
# Batch 308
# Batch correct = 9
#
# Batch 309
# Batch correct = 12
#
# Batch 310
# Batch correct = 7
#
# Batch 311
# Batch correct = 9
#
# Batch 312
# Batch correct = 9
#
# Batch 313
# Batch correct = 13
#
# Batch 314
# Batch correct = 10
#
# Batch 315
# Batch correct = 10
#
# Batch 316
# Batch correct = 9
#
# Batch 317
# Batch correct = 4
#
# Batch 318
# Batch correct = 9
#
# Batch 319
# Batch correct = 6
#
# Batch 320
# Batch correct = 11
#
# Batch 321
# Batch correct = 11
#
# Batch 322
# Batch correct = 8
#
# Batch 323
# Batch correct = 8
#
# Batch 324
# Batch correct = 10
#
# Batch 325
# Batch correct = 7
#
# Batch 326
# Batch correct = 12
#
# Batch 327
# Batch correct = 9
#
# Batch 328
# Batch correct = 11
#
# Batch 329
# Batch correct = 7
#
# Batch 330
# Batch correct = 10
#
# Batch 331
# Batch correct = 10
#
# Batch 332
# Batch correct = 11
#
# Batch 333
# Batch correct = 12
#
# Batch 334
# Batch correct = 8
#
# Batch 335
# Batch correct = 11
#
# Batch 336
# Batch correct = 11
#
# Batch 337
# Batch correct = 7
#
# Batch 338
# Batch correct = 10
#
# Batch 339
# Batch correct = 11
#
# Batch 340
# Batch correct = 11
#
# Batch 341
# Batch correct = 8
#
# Batch 342
# Batch correct = 11
#
# Batch 343
# Batch correct = 10
#
# Batch 344
# Batch correct = 8
#
# Batch 345
# Batch correct = 10
#
# Batch 346
# Batch correct = 12
#
# Batch 347
# Batch correct = 9
#
# Batch 348
# Batch correct = 9
#
# Batch 349
# Batch correct = 12
#
# Batch 350
# Batch correct = 11
#
# Batch 351
# Batch correct = 12
#
# Batch 352
# Batch correct = 10
#
# Batch 353
# Batch correct = 9
#
# Batch 354
# Batch correct = 8
#
# Batch 355
# Batch correct = 9
#
# Batch 356
# Batch correct = 9
#
# Batch 357
# Batch correct = 6
#
# Batch 358
# Batch correct = 9
#
# Batch 359
# Batch correct = 7
#
# Batch 360
# Batch correct = 9
#
# Batch 361
# Batch correct = 7
#
# Batch 362
# Batch correct = 10
#
# Batch 363
# Batch correct = 14
#
# Batch 364
# Batch correct = 12
#
# Batch 365
# Batch correct = 8
#
# Batch 366
# Batch correct = 8
#
# Batch 367
# Batch correct = 8
#
# Batch 368
# Batch correct = 8
#
# Batch 369
# Batch correct = 10
#
# Batch 370
# Batch correct = 7
#
# Batch 371
# Batch correct = 6
#
# Batch 372
# Batch correct = 12
#
# Batch 373
# Batch correct = 11
#
# Batch 374
# Batch correct = 11
#
# Batch 375
# Batch correct = 8
#
# Batch 376
# Batch correct = 9
#
# Batch 377
# Batch correct = 9
#
# Batch 378
# Batch correct = 10
#
# Batch 379
# Batch correct = 10
#
# Batch 380
# Batch correct = 9
#
# Batch 381
# Batch correct = 12
#
# Batch 382
# Batch correct = 8
#
# Batch 383
# Batch correct = 10
#
# Batch 384
# Batch correct = 11
#
# Batch 385
# Batch correct = 13
#
# Batch 386
# Batch correct = 6
#
# Batch 387
# Batch correct = 12
#
# Batch 388
# Batch correct = 10
#
# Batch 389
# Batch correct = 10
#
# Batch 390
# Batch correct = 12
#
# Batch 391
# Batch correct = 11
#
# Batch 392
# Batch correct = 9
#
# Batch 393
# Batch correct = 11
#
# Batch 394
# Batch correct = 12
#
# Batch 395
# Batch correct = 10
#
# Batch 396
# Batch correct = 8
#
# Batch 397
# Batch correct = 11
#
# Batch 398
# Batch correct = 8
#
# Batch 399
# Batch correct = 12
#
# Batch 400
# Batch correct = 8
#
# Batch 401
# Batch correct = 9
#
# Batch 402
# Batch correct = 8
#
# Batch 403
# Batch correct = 5
#
# Batch 404
# Batch correct = 7
#
# Batch 405
# Batch correct = 10
#
# Batch 406
# Batch correct = 8
#
# Batch 407
# Batch correct = 9
#
# Batch 408
# Batch correct = 9
#
# Batch 409
# Batch correct = 10
#
# Batch 410
# Batch correct = 8
#
# Batch 411
# Batch correct = 8
#
# Batch 412
# Batch correct = 11
#
# Batch 413
# Batch correct = 10
#
# Batch 414
# Batch correct = 8
#
# Batch 415
# Batch correct = 10
#
# Batch 416
# Batch correct = 12
#
# Batch 417
# Batch correct = 8
#
# Batch 418
# Batch correct = 9
#
# Batch 419
# Batch correct = 11
#
# Batch 420
# Batch correct = 11
#
# Batch 421
# Batch correct = 11
#
# Batch 422
# Batch correct = 8
#
# Batch 423
# Batch correct = 7
#
# Batch 424
# Batch correct = 9
#
# Batch 425
# Batch correct = 11
#
# Batch 426
# Batch correct = 9
#
# Batch 427
# Batch correct = 9
#
# Batch 428
# Batch correct = 10
#
# Batch 429
# Batch correct = 14
#
# Batch 430
# Batch correct = 9
#
# Batch 431
# Batch correct = 9
#
# Batch 432
# Batch correct = 11
#
# Batch 433
# Batch correct = 11
#
# Batch 434
# Batch correct = 10
#
# Batch 435
# Batch correct = 11
#
# Batch 436
# Batch correct = 7
#
# Batch 437
# Batch correct = 7
#
# Batch 438
# Batch correct = 10
#
# Batch 439
# Batch correct = 13
#
# Batch 440
# Batch correct = 10
#
# Batch 441
# Batch correct = 6
#
# Batch 442
# Batch correct = 6
#
# Batch 443
# Batch correct = 9
#
# Batch 444
# Batch correct = 11
#
# Batch 445
# Batch correct = 8
#
# Batch 446
# Batch correct = 10
#
# Batch 447
# Batch correct = 7
#
# Batch 448
# Batch correct = 15
#
# Batch 449
# Batch correct = 10
#
# Batch 450
# Batch correct = 12
#
# Batch 451
# Batch correct = 9
#
# Batch 452
# Batch correct = 12
#
# Batch 453
# Batch correct = 9
#
# Batch 454
# Batch correct = 11
#
# Batch 455
# Batch correct = 12
#
# Batch 456
# Batch correct = 8
#
# Batch 457
# Batch correct = 10
#
# Batch 458
# Batch correct = 10
#
# Batch 459
# Batch correct = 9
#
# Batch 460
# Batch correct = 9
#
# Batch 461
# Batch correct = 11
#
# Batch 462
# Batch correct = 6
#
# Batch 463
# Batch correct = 13
#
# Batch 464
# Batch correct = 10
#
# Batch 465
# Batch correct = 12
#
# Batch 466
# Batch correct = 10
#
# Batch 467
# Batch correct = 6
#
# Batch 468
# Batch correct = 12
#
# Batch 469
# Batch correct = 7
#
# Batch 470
# Batch correct = 8
#
# Batch 471
# Batch correct = 12
#
# Batch 472
# Batch correct = 13
#
# Batch 473
# Batch correct = 9
#
# Batch 474
# Batch correct = 8
#
# Batch 475
# Batch correct = 11
#
# Batch 476
# Batch correct = 9
#
# Batch 477
# Batch correct = 10
#
# Batch 478
# Batch correct = 8
#
# Batch 479
# Batch correct = 8
#
# Batch 480
# Batch correct = 13
#
# Batch 481
# Batch correct = 8
#
# Batch 482
# Batch correct = 9
#
# Batch 483
# Batch correct = 7
#
# Batch 484
# Batch correct = 10
#
# Batch 485
# Batch correct = 9
#
# Batch 486
# Batch correct = 10
#
# Batch 487
# Batch correct = 11
#
# Batch 488
# Batch correct = 10
#
# Batch 489
# Batch correct = 13
#
# Batch 490
# Batch correct = 9
#
# Batch 491
# Batch correct = 10
#
# Batch 492
# Batch correct = 8
#
# Batch 493
# Batch correct = 10
#
# Batch 494
# Batch correct = 10
#
# Batch 495
# Batch correct = 7
#
# Batch 496
# Batch correct = 9
#
# Batch 497
# Batch correct = 6
#
# Batch 498
# Batch correct = 12
#
# Batch 499
# Batch correct = 11
#
# Batch 500
# Batch correct = 12
#
# Batch 501
# Batch correct = 12
#
# Batch 502
# Batch correct = 12
#
# Batch 503
# Batch correct = 9
#
# Batch 504
# Batch correct = 10
#
# Batch 505
# Batch correct = 9
#
# Batch 506
# Batch correct = 8
#
# Batch 507
# Batch correct = 9
#
# Batch 508
# Batch correct = 15
#
# Batch 509
# Batch correct = 11
#
# Batch 510
# Batch correct = 9
#
# Batch 511
# Batch correct = 14
#
# Batch 512
# Batch correct = 7
#
# Batch 513
# Batch correct = 7
#
# Batch 514
# Batch correct = 8
#
# Batch 515
# Batch correct = 10
#
# Batch 516
# Batch correct = 10
#
# Batch 517
# Batch correct = 11
#
# Batch 518
# Batch correct = 5
#
# Batch 519
# Batch correct = 11
#
# Batch 520
# Batch correct = 10
#
# Batch 521
# Batch correct = 13
#
# Batch 522
# Batch correct = 10
#
# Batch 523
# Batch correct = 11
#
# Batch 524
# Batch correct = 11
#
# Batch 525
# Batch correct = 12
#
# Batch 526
# Batch correct = 11
#
# Batch 527
# Batch correct = 11
#
# Batch 528
# Batch correct = 12
#
# Batch 529
# Batch correct = 13
#
# Batch 530
# Batch correct = 8
#
# Batch 531
# Batch correct = 13
#
# Batch 532
# Batch correct = 7
#
# Batch 533
# Batch correct = 9
#
# Batch 534
# Batch correct = 12
#
# Batch 535
# Batch correct = 8
#
# Batch 536
# Batch correct = 9
#
# Batch 537
# Batch correct = 10
#
# Batch 538
# Batch correct = 11
#
# Batch 539
# Batch correct = 10
#
# Batch 540
# Batch correct = 9
#
# Batch 541
# Batch correct = 14
#
# Batch 542
# Batch correct = 9
#
# Batch 543
# Batch correct = 11
#
# Batch 544
# Batch correct = 10
#
# Batch 545
# Batch correct = 13
#
# Batch 546
# Batch correct = 12
#
# Batch 547
# Batch correct = 10
#
# Batch 548
# Batch correct = 6
#
# Batch 549
# Batch correct = 10
#
# Batch 550
# Batch correct = 9
#
# Batch 551
# Batch correct = 8
#
# Batch 552
# Batch correct = 9
#
# Batch 553
# Batch correct = 8
#
# Batch 554
# Batch correct = 8
#
# Batch 555
# Batch correct = 10
#
# Batch 556
# Batch correct = 12
#
# Batch 557
# Batch correct = 7
#
# Batch 558
# Batch correct = 6
#
# Batch 559
# Batch correct = 12
#
# Batch 560
# Batch correct = 12
#
# Batch 561
# Batch correct = 9
#
# Batch 562
# Batch correct = 13
#
# Batch 563
# Batch correct = 12
#
# Batch 564
# Batch correct = 8
#
# Batch 565
# Batch correct = 13
#
# Batch 566
# Batch correct = 11
#
# Batch 567
# Batch correct = 5
#
# Batch 568
# Batch correct = 12
#
# Batch 569
# Batch correct = 5
#
# Batch 570
# Batch correct = 6
#
# Batch 571
# Batch correct = 10
#
# Batch 572
# Batch correct = 9
#
# Batch 573
# Batch correct = 8
#
# Batch 574
# Batch correct = 10
#
# Batch 575
# Batch correct = 8
#
# Batch 576
# Batch correct = 7
#
# Batch 577
# Batch correct = 13
#
# Batch 578
# Batch correct = 10
#
# Batch 579
# Batch correct = 14
#
# Batch 580
# Batch correct = 10
#
# Batch 581
# Batch correct = 10
#
# Batch 582
# Batch correct = 10
#
# Batch 583
# Batch correct = 7
#
# Batch 584
# Batch correct = 9
#
# Batch 585
# Batch correct = 8
#
# Batch 586
# Batch correct = 11
#
# Batch 587
# Batch correct = 9
#
# Batch 588
# Batch correct = 12
#
# Batch 589
# Batch correct = 11
#
# Batch 590
# Batch correct = 10
#
# Batch 591
# Batch correct = 12
#
# Batch 592
# Batch correct = 6
#
# Batch 593
# Batch correct = 10
#
# Batch 594
# Batch correct = 8
#
# Batch 595
# Batch correct = 8
#
# Batch 596
# Batch correct = 14
#
# Batch 597
# Batch correct = 10
#
# Batch 598
# Batch correct = 11
#
# Batch 599
# Batch correct = 10
#
# Batch 600
# Batch correct = 10
#
# Batch 601
# Batch correct = 12
#
# Batch 602
# Batch correct = 10
#
# Batch 603
# Batch correct = 6
#
# Batch 604
# Batch correct = 12
#
# Batch 605
# Batch correct = 10
#
# Batch 606
# Batch correct = 13
#
# Batch 607
# Batch correct = 9
#
# Batch 608
# Batch correct = 10
#
# Batch 609
# Batch correct = 9
#
# Batch 610
# Batch correct = 13
#
# Batch 611
# Batch correct = 7
#
# Batch 612
# Batch correct = 11
#
# Batch 613
# Batch correct = 11
#
# Batch 614
# Batch correct = 11
#
# Batch 615
# Batch correct = 10
#
# Batch 616
# Batch correct = 6
#
# Batch 617
# Batch correct = 12
#
# Batch 618
# Batch correct = 10
#
# Batch 619
# Batch correct = 12
#
# Batch 620
# Batch correct = 12
#
# Batch 621
# Batch correct = 10
#
# Batch 622
# Batch correct = 9
#
# Batch 623
# Batch correct = 10
#
# Batch 624
# Batch correct = 11
#
# Batch 625
# Batch correct = 9
#
# Batch 626
# Batch correct = 14
#
# Batch 627
# Batch correct = 13
#
# Batch 628
# Batch correct = 11
#
# Batch 629
# Batch correct = 10
#
# Batch 630
# Batch correct = 7
#
# Batch 631
# Batch correct = 11
#
# Batch 632
# Batch correct = 13
#
# Batch 633
# Batch correct = 11
#
# Batch 634
# Batch correct = 4
#
# Batch 635
# Batch correct = 13
#
# Batch 636
# Batch correct = 10
#
# Batch 637
# Batch correct = 6
#
# Batch 638
# Batch correct = 12
#
# Batch 639
# Batch correct = 8
#
# Batch 640
# Batch correct = 10
#
# Batch 641
# Batch correct = 8
#
# Batch 642
# Batch correct = 11
#
# Batch 643
# Batch correct = 7
#
# Batch 644
# Batch correct = 10
#
# Batch 645
# Batch correct = 7
#
# Batch 646
# Batch correct = 8
#
# Batch 647
# Batch correct = 7
#
# Batch 648
# Batch correct = 11
#
# Batch 649
# Batch correct = 9
#
# Batch 650
# Batch correct = 12
#
# Batch 651
# Batch correct = 9
#
# Batch 652
# Batch correct = 12
#
# Batch 653
# Batch correct = 7
#
# Batch 654
# Batch correct = 8
#
# Batch 655
# Batch correct = 8
#
# Batch 656
# Batch correct = 13
#
# Batch 657
# Batch correct = 10
#
# Batch 658
# Batch correct = 9
#
# Batch 659
# Batch correct = 10
#
# Batch 660
# Batch correct = 12
#
# Batch 661
# Batch correct = 7
#
# Batch 662
# Batch correct = 13
#
# Batch 663
# Batch correct = 8
#
# Batch 664
# Batch correct = 7
#
# Batch 665
# Batch correct = 9
#
# Batch 666
# Batch correct = 11
#
# Batch 667
# Batch correct = 11
#
# Batch 668
# Batch correct = 8
#
# Batch 669
# Batch correct = 11
#
# Batch 670
# Batch correct = 8
#
# Batch 671
# Batch correct = 11
#
# Batch 672
# Batch correct = 9
#
# Batch 673
# Batch correct = 11
#
# Batch 674
# Batch correct = 7
#
# Batch 675
# Batch correct = 7
#
# Batch 676
# Batch correct = 11
#
# Batch 677
# Batch correct = 7
#
# Batch 678
# Batch correct = 12
#
# Batch 679
# Batch correct = 11
#
# Batch 680
# Batch correct = 12
#
# Batch 681
# Batch correct = 10
#
# Batch 682
# Batch correct = 10
#
# Batch 683
# Batch correct = 12
#
# Batch 684
# Batch correct = 10
#
# Batch 685
# Batch correct = 12
#
# Batch 686
# Batch correct = 11
#
# Batch 687
# Batch correct = 8
#
# Batch 688
# Batch correct = 12
#
# Batch 689
# Batch correct = 7
#
# Batch 690
# Batch correct = 10
#
# Batch 691
# Batch correct = 5
#
# Batch 692
# Batch correct = 9
#
# Batch 693
# Batch correct = 10
#
# Batch 694
# Batch correct = 10
#
# Batch 695
# Batch correct = 11
#
# Batch 696
# Batch correct = 9
#
# Batch 697
# Batch correct = 13
#
# Batch 698
# Batch correct = 8
#
# Batch 699
# Batch correct = 10
#
# Batch 700
# Batch correct = 7
#
# Batch 701
# Batch correct = 10
#
# Batch 702
# Batch correct = 12
#
# Batch 703
# Batch correct = 10
#
# Batch 704
# Batch correct = 9
#
# Batch 705
# Batch correct = 9
#
# Batch 706
# Batch correct = 15
#
# Batch 707
# Batch correct = 12
#
# Batch 708
# Batch correct = 10
#
# Batch 709
# Batch correct = 5
#
# Batch 710
# Batch correct = 12
#
# Batch 711
# Batch correct = 12
#
# Batch 712
# Batch correct = 11
#
# Batch 713
# Batch correct = 9
#
# Batch 714
# Batch correct = 8
#
# Batch 715
# Batch correct = 9
#
# Batch 716
# Batch correct = 13
#
# Batch 717
# Batch correct = 9
#
# Batch 718
# Batch correct = 7
#
# Batch 719
# Batch correct = 11
#
# Batch 720
# Batch correct = 11
#
# Batch 721
# Batch correct = 8
#
# Batch 722
# Batch correct = 12
#
# Batch 723
# Batch correct = 12
#
# Batch 724
# Batch correct = 8
#
# Batch 725
# Batch correct = 9
#
# Batch 726
# Batch correct = 10
#
# Batch 727
# Batch correct = 10
#
# Batch 728
# Batch correct = 6
#
# Batch 729
# Batch correct = 12
#
# Batch 730
# Batch correct = 13
#
# Batch 731
# Batch correct = 7
#
# Batch 732
# Batch correct = 10
#
# Batch 733
# Batch correct = 5
#
# Batch 734
# Batch correct = 12
#
# Batch 735
# Batch correct = 6
#
# Batch 736
# Batch correct = 12
#
# Batch 737
# Batch correct = 10
#
# Batch 738
# Batch correct = 11
#
# Batch 739
# Batch correct = 13
#
# Batch 740
# Batch correct = 10
#
# Batch 741
# Batch correct = 12
#
# Batch 742
# Batch correct = 13
#
# Batch 743
# Batch correct = 11
#
# Batch 744
# Batch correct = 6
#
# Batch 745
# Batch correct = 11
#
# Batch 746
# Batch correct = 11
#
# Batch 747
# Batch correct = 7
#
# Batch 748
# Batch correct = 12
#
# Batch 749
# Batch correct = 8
#
# Batch 750
# Batch correct = 7
#
# Batch 751
# Batch correct = 11
#
# Batch 752
# Batch correct = 11
#
# Batch 753
# Batch correct = 10
#
# Batch 754
# Batch correct = 8
#
# Batch 755
# Batch correct = 12
#
# Batch 756
# Batch correct = 9
#
# Batch 757
# Batch correct = 11
#
# Batch 758
# Batch correct = 8
#
# Batch 759
# Batch correct = 10
#
# Batch 760
# Batch correct = 10
#
# Batch 761
# Batch correct = 7
#
# Batch 762
# Batch correct = 12
#
# Batch 763
# Batch correct = 11
#
# Batch 764
# Batch correct = 9
#
# Batch 765
# Batch correct = 9
#
# Batch 766
# Batch correct = 9
#
# Batch 767
# Batch correct = 9
#
# Batch 768
# Batch correct = 10
#
# Batch 769
# Batch correct = 10
#
# Batch 770
# Batch correct = 10
#
# Batch 771
# Batch correct = 7
#
# Batch 772
# Batch correct = 9
#
# Batch 773
# Batch correct = 9
#
# Batch 774
# Batch correct = 8
#
# Batch 775
# Batch correct = 9
#
# Batch 776
# Batch correct = 8
#
# Batch 777
# Batch correct = 11
#
# Batch 778
# Batch correct = 12
#
# Batch 779
# Batch correct = 8
#
# Batch 780
# Batch correct = 8
#
# Batch 781
# Batch correct = 7
#
# Batch 782
# Batch correct = 7
#
# Batch 783
# Batch correct = 11
#
# Batch 784
# Batch correct = 11
#
# Batch 785
# Batch correct = 11
#
# Batch 786
# Batch correct = 8
#
# Batch 787
# Batch correct = 7
#
# Batch 788
# Batch correct = 12
#
# Batch 789
# Batch correct = 10
#
# Batch 790
# Batch correct = 12
#
# Batch 791
# Batch correct = 13
#
# Batch 792
# Batch correct = 9
#
# Batch 793
# Batch correct = 11
#
# Batch 794
# Batch correct = 11
#
# Batch 795
# Batch correct = 8
#
# Batch 796
# Batch correct = 6
#
# Batch 797
# Batch correct = 12
#
# Batch 798
# Batch correct = 9
#
# Batch 799
# Batch correct = 8
#
# Batch 800
# Batch correct = 9
#
# Batch 801
# Batch correct = 13
#
# Batch 802
# Batch correct = 9
#
# Batch 803
# Batch correct = 9
#
# Batch 804
# Batch correct = 9
#
# Batch 805
# Batch correct = 11
#
# Batch 806
# Batch correct = 8
#
# Batch 807
# Batch correct = 8
#
# Batch 808
# Batch correct = 12
#
# Batch 809
# Batch correct = 8
#
# Batch 810
# Batch correct = 13
#
# Batch 811
# Batch correct = 11
#
# Batch 812
# Batch correct = 12
#
# Batch 813
# Batch correct = 11
#
# Batch 814
# Batch correct = 11
#
# Batch 815
# Batch correct = 11
#
# Batch 816
# Batch correct = 9
#
# Batch 817
# Batch correct = 7
#
# Batch 818
# Batch correct = 10
#
# Batch 819
# Batch correct = 8
#
# Batch 820
# Batch correct = 11
#
# Batch 821
# Batch correct = 10
#
# Batch 822
# Batch correct = 14
#
# Batch 823
# Batch correct = 11
#
# Batch 824
# Batch correct = 9
#
# Batch 825
# Batch correct = 10
#
# Batch 826
# Batch correct = 6
#
# Batch 827
# Batch correct = 7
#
# Batch 828
# Batch correct = 12
#
# Batch 829
# Batch correct = 11
#
# Batch 830
# Batch correct = 10
#
# Batch 831
# Batch correct = 10
#
# Batch 832
# Batch correct = 9
#
# Batch 833
# Batch correct = 7
#
# Batch 834
# Batch correct = 7
#
# Batch 835
# Batch correct = 12
#
# Batch 836
# Batch correct = 8
#
# Batch 837
# Batch correct = 10
#
# Batch 838
# Batch correct = 5
#
# Batch 839
# Batch correct = 11
#
# Batch 840
# Batch correct = 12
#
# Batch 841
# Batch correct = 7
#
# Batch 842
# Batch correct = 9
#
# Batch 843
# Batch correct = 11
#
# Batch 844
# Batch correct = 9
#
# Batch 845
# Batch correct = 9
#
# Batch 846
# Batch correct = 11
#
# Batch 847
# Batch correct = 11
#
# Batch 848
# Batch correct = 11
#
# Batch 849
# Batch correct = 8
#
# Batch 850
# Batch correct = 7
#
# Batch 851
# Batch correct = 9
#
# Batch 852
# Batch correct = 8
#
# Batch 853
# Batch correct = 8
#
# Batch 854
# Batch correct = 9
#
# Batch 855
# Batch correct = 9
#
# Batch 856
# Batch correct = 8
#
# Batch 857
# Batch correct = 8
#
# Batch 858
# Batch correct = 11
#
# Batch 859
# Batch correct = 9
#
# Batch 860
# Batch correct = 14
#
# Batch 861
# Batch correct = 6
#
# Batch 862
# Batch correct = 12
#
# Batch 863
# Batch correct = 11
#
# Batch 864
# Batch correct = 6
#
# Batch 865
# Batch correct = 7
#
# Batch 866
# Batch correct = 13
#
# Batch 867
# Batch correct = 9
#
# Batch 868
# Batch correct = 13
#
# Batch 869
# Batch correct = 9
#
# Batch 870
# Batch correct = 9
#
# Batch 871
# Batch correct = 10
#
# Batch 872
# Batch correct = 9
#
# Batch 873
# Batch correct = 10
#
# Batch 874
# Batch correct = 8
#
# Batch 875
# Batch correct = 10
#
# Batch 876
# Batch correct = 13
#
# Batch 877
# Batch correct = 9
#
# Batch 878
# Batch correct = 8
#
# Batch 879
# Batch correct = 11
#
# Batch 880
# Batch correct = 4
#
# Batch 881
# Batch correct = 8
#
# Batch 882
# Batch correct = 8
#
# Batch 883
# Batch correct = 10
#
# Batch 884
# Batch correct = 10
#
# Batch 885
# Batch correct = 11
#
# Batch 886
# Batch correct = 11
#
# Batch 887
# Batch correct = 8
#
# Batch 888
# Batch correct = 9
#
# Batch 889
# Batch correct = 9
#
# Batch 890
# Batch correct = 8
#
# Batch 891
# Batch correct = 10
#
# Batch 892
# Batch correct = 7
#
# Batch 893
# Batch correct = 11
#
# Batch 894
# Batch correct = 11
#
# Batch 895
# Batch correct = 10
#
# Batch 896
# Batch correct = 12
#
# Batch 897
# Batch correct = 8
#
# Batch 898
# Batch correct = 12
#
# Batch 899
# Batch correct = 12
#
# Batch 900
# Batch correct = 10
#
# Batch 901
# Batch correct = 5
#
# Batch 902
# Batch correct = 12
#
# Batch 903
# Batch correct = 13
#
# Batch 904
# Batch correct = 8
#
# Batch 905
# Batch correct = 11
#
# Batch 906
# Batch correct = 10
#
# Batch 907
# Batch correct = 11
#
# Batch 908
# Batch correct = 13
#
# Batch 909
# Batch correct = 9
#
# Batch 910
# Batch correct = 10
#
# Batch 911
# Batch correct = 11
#
# Batch 912
# Batch correct = 5
#
# Batch 913
# Batch correct = 8
#
# Batch 914
# Batch correct = 8
#
# Batch 915
# Batch correct = 12
#
# Batch 916
# Batch correct = 9
#
# Batch 917
# Batch correct = 9
#
# Batch 918
# Batch correct = 8
#
# Batch 919
# Batch correct = 5
#
# Batch 920
# Batch correct = 8
#
# Batch 921
# Batch correct = 12
#
# Batch 922
# Batch correct = 11
#
# Batch 923
# Batch correct = 11
#
# Batch 924
# Batch correct = 12
#
# Batch 925
# Batch correct = 8
#
# Batch 926
# Batch correct = 7
#
# Batch 927
# Batch correct = 8
#
# Batch 928
# Batch correct = 10
#
# Batch 929
# Batch correct = 11
#
# Batch 930
# Batch correct = 7
#
# Batch 931
# Batch correct = 8
#
# Batch 932
# Batch correct = 7
#
# Batch 933
# Batch correct = 9
#
# Batch 934
# Batch correct = 9
#
# Batch 935
# Batch correct = 6
#
# Batch 936
# Batch correct = 11
#
# Batch 937
# Batch correct = 8
#
# Batch 938
# Batch correct = 10
#
# Batch 939
# Batch correct = 9
#
# Batch 940
# Batch correct = 10
#
# Batch 941
# Batch correct = 9
#
# Batch 942
# Batch correct = 9
#
# Batch 943
# Batch correct = 10
#
# Batch 944
# Batch correct = 9
#
# Batch 945
# Batch correct = 11
#
# Batch 946
# Batch correct = 13
#
# Batch 947
# Batch correct = 10
#
# Batch 948
# Batch correct = 14
#
# Batch 949
# Batch correct = 12
#
# Batch 950
# Batch correct = 12
#
# Batch 951
# Batch correct = 9
#
# Batch 952
# Batch correct = 8
#
# Batch 953
# Batch correct = 10
#
# Batch 954
# Batch correct = 9
#
# Batch 955
# Batch correct = 10
#
# Batch 956
# Batch correct = 11
#
# Batch 957
# Batch correct = 8
#
# Batch 958
# Batch correct = 6
#
# Batch 959
# Batch correct = 7
#
# Batch 960
# Batch correct = 11
#
# Batch 961
# Batch correct = 12
#
# Batch 962
# Batch correct = 12
#
# Batch 963
# Batch correct = 10
#
# Batch 964
# Batch correct = 10
#
# Batch 965
# Batch correct = 6
#
# Batch 966
# Batch correct = 8
#
# Batch 967
# Batch correct = 10
#
# Batch 968
# Batch correct = 8
#
# Batch 969
# Batch correct = 10
#
# Batch 970
# Batch correct = 10
#
# Batch 971
# Batch correct = 9
#
# Batch 972
# Batch correct = 11
#
# Batch 973
# Batch correct = 11
#
# Batch 974
# Batch correct = 12
#
# Batch 975
# Batch correct = 8
#
# Batch 976
# Batch correct = 14
#
# Batch 977
# Batch correct = 10
#
# Batch 978
# Batch correct = 7
#
# Batch 979
# Batch correct = 10
#
# Batch 980
# Batch correct = 8
#
# Batch 981
# Batch correct = 10
#
# Batch 982
# Batch correct = 13
#
# Batch 983
# Batch correct = 11
#
# Batch 984
# Batch correct = 10
#
# Batch 985
# Batch correct = 9
#
# Batch 986
# Batch correct = 10
#
# Batch 987
# Batch correct = 14
#
# Batch 988
# Batch correct = 10
#
# Batch 989
# Batch correct = 11
#
# Batch 990
# Batch correct = 9
#
# Batch 991
# Batch correct = 12
#
# Batch 992
# Batch correct = 8
#
# Batch 993
# Batch correct = 9
#
# Batch 994
# Batch correct = 12
#
# Batch 995
# Batch correct = 9
#
# Batch 996
# Batch correct = 11
#
# Batch 997
# Batch correct = 12
#
# Batch 998
# Batch correct = 10
#
# Batch 999
# Batch correct = 10
#
# Batch 1000
# Batch correct = 10
#
# DONE.
# Total correct =  9736
# Test accuracy = 0.61
#               precision    recall  f1-score   support
#
#            0       0.62      0.57      0.59      8021
#            1       0.60      0.65      0.62      7979
#
#     accuracy                           0.61     16000
#    macro avg       0.61      0.61      0.61     16000
# weighted avg       0.61      0.61      0.61     16000
#
# [[4585 3436]
#  [2828 5151]]
